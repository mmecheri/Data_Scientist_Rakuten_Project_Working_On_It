# %% [markdown]
# # 21 - Image Final Tuning
#
# ### Context:
#
# This notebook focuses on **Step 5 - Final Tuning**, where we will re-train the five models with the optimal learning rates (LR) identified in the previous step. We will also apply **data augmentation** to enhance model performance and generalization.
#
# ### Objective:
# - **Re-train the five models** with the optimal LR values:
#   - **DenseNet121**: LR = **[insert best LR here]**
#   - **MobileNetV2**: LR = **[insert best LR here]**
#   - **InceptionResNetV2**: **[insert best LR here]**
#   - **Xception**: LR = **[0.000106]**
#   - **InceptionV3**: LR =**[0.000225]**
#
# - **Data Augmentation**: To improve generalization and performance, we will augment the training data.
# - **Fine-tuning**: Each model will be fine-tuned to optimize performance further.
#
# By the end of this notebook, we will have fine-tuned models optimized for performance and generalization on our imbalanced dataset.

# %% [markdown]
# ##  2. Import Required Libraries & Configuration

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import os
import sys
from pathlib import Path
import importlib

# Data science and visualization libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# TensorFlow and Keras libraries for model building and image preprocessing
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Scikit-learn metrics for model evaluation
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score

# Setup dynamic project paths
CURRENT_DIR = Path(os.getcwd()).resolve()
PROJECT_ROOT = CURRENT_DIR.parents[2]
sys.path.append(str(PROJECT_ROOT))

def get_relative_path(absolute_path):
    return str(Path(absolute_path).relative_to(PROJECT_ROOT))

print(f"Project Root Directory: {PROJECT_ROOT.name}")

# Load project config and modules from src
import config
# Out:
# Project Root Directory: Data_Scientist_Rakuten_Project-main

# %% [markdown]
#  ## 3.  Meta data import and Preprocessing

# %% [markdown]
#  ### 3.1 Import Image Metadata

# %%
import src.data_preprocessing.load_image_metadata
importlib.reload(src.data_preprocessing.load_image_metadata)
from src.data_preprocessing.load_image_metadata import load_image_metadata
from sklearn.utils.class_weight import compute_class_weight

# Call the function
X_train_split, X_val_split, prdtypecode_mapping = load_image_metadata()
# Out:
# [✔] Loaded `X_train_split` | Type: <class 'pandas.core.frame.DataFrame'>
#                                             designation  \
# 1887  porte bebe violet rouge trois mere multifoncti...
#
#                                             description  \
# 1887  Porte bébé Violet et rouge Trois-en-un mère mu...
#
#                                                    text   productid  \
# 1887  porte bebe violet rouge trois mere multifoncti...  3050424970
#
#          imageid  prdtypecode  prdtypecode_encoded            Label  \
# 1887  1187504001         1320                   12  Early Childhood
#
#                                    image_name
# 1887  image_1187504001_product_3050424970.jpg
# [✔] Loaded `X_val_split` | Type: <class 'pandas.core.frame.DataFrame'>
#                                              designation  \
# 81432  bas filles enfants enfants collant coton bebe ...
#
#                                              description  \
# 81432  Filles Bas Enfants Enfants Collant Coton bébé ...
#
#                                                     text   productid  \
# 81432  bas filles enfants collant coton bebe stocking...  3898715946
#
#           imageid  prdtypecode  prdtypecode_encoded                     Label  \
# 81432  1261369347         1301                   10  Accessories for Children
#
#                                     image_name
# 81432  image_1261369347_product_3898715946.jpg
# [✔] Loaded `prdtypecode_mapping` | Type: <class 'dict'>
#  Sample entries from `prdtypecode_mapping`: [(10, 0), (40, 1), (50, 2), (60, 3), (1140, 4)]

# %% [markdown]
# # **************** Samples for testing  TO DEL

# %%
# import src.data_preprocessing.load_image_metadata
# importlib.reload(src.data_preprocessing.load_image_metadata)
# from src.data_preprocessing.load_image_metadata import load_image_metadata


# X_train_split_full , X_val_split_full, prdtypecode_mapping = load_image_metadata()


# # Nombre d'échantillons par classe à prendre (ajustez selon la taille de votre sous-échantillon)
# samples_per_class = 20  # Par exemple, prendre 40 images par classe

# # Sélectionner un échantillon aléatoire de chaque classe pour l'ensemble d'entraînement
# X_train_split = X_train_split_full.groupby('prdtypecode_encoded', group_keys=False).apply(
#     lambda x: x.sample(n=min(samples_per_class, len(x)), random_state=42)
# )

# # Sélectionner un échantillon aléatoire de chaque classe pour l'ensemble de validation
# X_val_split = X_val_split_full.groupby('prdtypecode_encoded', group_keys=False).apply(
#     lambda x: x.sample(n=min(samples_per_class, len(x)), random_state=42)
# )

# # Réinitialiser les index après avoir effectué l'échantillonnage
# X_train_split = X_train_split.reset_index(drop=True)
# X_val_split = X_val_split.reset_index(drop=True)

# # Afficher les tailles des sous-échantillons
# print(f"\n{'='*50}")
# print(f"Train sample size: {X_train_split.shape}")
# print(f"Validation sample size: {X_val_split.shape}")
# print(f"\n{'='*50}")

# %% [markdown]
#  ### 3.2 Class Weights Calculation

# %%
class_labels = np.unique(X_train_split["prdtypecode_encoded"])
class_counts = {label: np.sum(X_train_split["prdtypecode_encoded"] == label) for label in class_labels}

print('\nclass_counts:')
print(class_counts)

# Compute class weights based on distribution
class_weights = compute_class_weight('balanced', classes=class_labels, y=X_train_split["prdtypecode_encoded"])
class_weight_dict = {class_labels[i]: class_weights[i] for i in range(len(class_labels))}
class_weight_dict = {int(key): value for key, value in class_weight_dict.items()}

for label, weight in list(class_weight_dict.items())[:5]:
    print(f"Class {label}: Adjusted weight: {weight}")
# Out:
# class_counts:
# {0: 2493, 1: 2006, 2: 1345, 3: 666, 4: 2137, 5: 3162, 6: 611, 7: 3896, 8: 1656, 9: 4036, 10: 646, 11: 1993, 12: 2593, 13: 4058, 14: 3442, 15: 642, 16: 3994, 17: 659, 18: 3808, 19: 3819, 20: 1137, 21: 3991, 22: 2071, 23: 8167, 24: 1997, 25: 2209, 26: 698}
# Class 0: Adjusted weight: 1.0092258323305254
# Class 1: Adjusted weight: 1.2542372881355932
# Class 2: Adjusted weight: 1.870631970260223
# Class 3: Adjusted weight: 3.7777777777777777
# Class 4: Adjusted weight: 1.1773514272344408

# %% [markdown]
#  ## 4. Global Training Parameters

# %% [markdown]
# ### 4.1 Training Parameters

# %%
# Training parameters
NUM_CLASSES = 27

# # #Quick testing
# EPOCHS = 1 
# BATCH_SIZE = 32


EPOCHS = 40
BATCH_SIZE = 64


class_names = [str(key) for key in prdtypecode_mapping.keys()]

in_shape_224 = (224,224,3)
in_shape_299 = (299,299,3)

MODEL_DIR = Path(config.FINAL_TRAINING_DIR)
STEP_NAME = 'Step5'

# %% [markdown]
#  ### 4.2 Data Generators for Augmentation

# %%
import src.modeling_image.data_augmentation
importlib.reload(src.modeling_image.data_augmentation)
from src.modeling_image.data_augmentation import create_data_augmentation_generator


#  Data Generators for  MobileNetV2, DenseNet121 (224x224)
train_gen_224x224, valid_gen_224x224 = create_data_augmentation_generator(
    input_size=(224, 224),  # For models that use (224, 224)
    batch_size=BATCH_SIZE, 
    train_data=X_train_split, 
    validation_data=X_val_split, 
    augment=True
)

#  Data Generators for  InceptionResNetV2, Xception, InceptionV3 (299x299)
train_gen_299x299, valid_gen_299x299 = create_data_augmentation_generator(
    input_size=(299, 299),  # For models that use (299, 299)
    batch_size=BATCH_SIZE, 
    train_data=X_train_split, 
    validation_data=X_val_split, 
    augment=True
)
# Out:
# ==================================================
# Received arguments:
# input_size          : (224, 224)
# batch_size          : 64
# augment             : True
# train_data_shape    : (67932, 9)
# validation_data_shape: (16984, 9)
# ==================================================
#
# Found 67932 validated image filenames belonging to 27 classes.
# Found 16984 validated image filenames belonging to 27 classes.
#
# ==================================================
# Received arguments:
# input_size          : (299, 299)
# batch_size          : 64
# augment             : True
# train_data_shape    : (67932, 9)
# validation_data_shape: (16984, 9)
# ==================================================
#
# Found 67932 validated image filenames belonging to 27 classes.
# Found 16984 validated image filenames belonging to 27 classes.

# %% [markdown]
# ## 5. Model Training and Evaluation

# %%
# Import necessary libraries and modules
import src.modeling_image.model_builder
importlib.reload(src.modeling_image.model_builder)
from src.modeling_image.model_builder import build_model

from src.modeling_image.cnn_training import train_model_and_save 
importlib.reload(src.modeling_image.cnn_training)
from src.modeling_image.cnn_training import train_model_and_save

from src.modeling_image.cnn_evaluation import evaluate_model 
importlib.reload(src.modeling_image.cnn_evaluation)
from src.modeling_image.cnn_evaluation import evaluate_model


from src.modeling_image.cnn_evaluation import evaluate_model 
importlib.reload(src.modeling_image.cnn_evaluation)
from src.modeling_image.cnn_evaluation import evaluate_model


importlib.reload(config)  # Reload config to ensure any updates are applied

# Notes:
# - 'model_builder.py' is used to build the model based on architecture.
# - 'cnn_training.py' contains the function to train the model and callbacks for monitoring the training process.
# - 'cnn_evaluation.py' is used for evaluating the model performance after training.
# - 'config.py' containes config settings like directories applied in the notebook.
# Out:
# <module 'config' from 'D:\\Data_Science\\Append_Data_Engineer_AWS_MLOPS\\Data_Scientist_Rakuten_Project-main\\config.py'>

# %% [markdown]
# ### 5.1 Training and Evaluation for DenseNet121

# %% [markdown]
# #### 5.1.1 Model Building and Compilation - DenseNet121

# %%
model_name = 'DenseNet121' 

# Define the number of layers to unfreeze
unfreeze_layers = 8

#Initialize the model using the build_model function.
model = build_model(
    model_name=model_name,
    input_shape=in_shape_224,
    num_classes=NUM_CLASSES,
    unfreeze_last_layers_count=unfreeze_layers  
)

# %% [markdown]
# #### 5.1.2 Training - DenseNet121

# %%
# %%time

LEARNING_RATE = ???
# Calling the train_model_and_save function 
model, history = train_model_and_save(
    model=model,
    train_data=train_gen_224x224,   # The subset of training data
    val_data=valid_gen_224x224,       # The subset of validation data
    epochs=EPOCHS,               
    batch_size=BATCH_SIZE,       
    class_weight_dict=class_weight_dict,  # Apply class weights 
    learning_rate=LEARNING_RATE,          
    model_name=model_name,          # The model name for saving
    save_model_dir= MODEL_DIR,      # Directory to save the model and checkpoints
    step_name = STEP_NAME           #The current step name (e.g., 'Step2', 'Step3') for proper file naming
)

# %% [markdown]
# #### 5.1.3 Evaluation -DenseNet121

# %%
# Call the evaluate_model function 
evaluate_model(
    model=model,
    test_data=valid_gen_224x224,  # The test data generator or dataset
    history=history,              # Pass the training history to display learning curves
    model_name=model_name,      # Name of the model
    class_names=class_names,      # List of class names (0-26)
    plot_curve=True,              # Display the learning curve (optional)
    plot_cm=True,                 # Display the confusion matrix (optional)
    report=True                   # Display the classification report (optional)
)

# %% [markdown]
# ---

# %% [markdown]
# ### 5.2 Training and Evaluation for MobileNetV2

# %% [markdown]
# #### 5.2.1 Model Building and Compilation - MobileNetV2

# %%
model_name = 'MobileNetV2' 

# Define the number of layers to unfreeze
unfreeze_layers = 8

#Initialize the model using the build_model function.
model = build_model(
    model_name=model_name,
    input_shape=in_shape_224,
    num_classes=NUM_CLASSES,
    unfreeze_last_layers_count=unfreeze_layers  
)

# %% [markdown]
# #### 5.2.2 Training - MobileNetV2

# %%
# %%time

LEARNING_RATE = ???

# Calling the train_model_and_save function
model, history = train_model_and_save(
    model=model,
    train_data=train_gen_224x224,   # The subset of training data
    val_data=valid_gen_224x224,       # The subset of validation data
    epochs=EPOCHS,                 
    batch_size=BATCH_SIZE,         
    class_weight_dict=class_weight_dict,  # Apply class weights 
    learning_rate=LEARNING_RATE,   
    model_name=model_name,          # The model name for saving
    save_model_dir= MODEL_DIR,      # Directory to save the model and checkpoints
    step_name = STEP_NAME         # The current step name (e.g., 'Step2', 'Step3') for proper file naming
)

# %% [markdown]
# #### 5.2.3 Evaluation - MobileNetV2

# %%
# Call the evaluate_model function 
evaluate_model(
    model=model,
    test_data=valid_gen_224x224,  # The test data generator or dataset
    history=history,              # Pass the training history to display learning curves
    model_name=model_name,      # Name of the model
    class_names=class_names,      # List of class names (0-26)
    plot_curve=True,              # Display the learning curve (optional)
    plot_cm=True,                 # Display the confusion matrix (optional)
    report=True                   # Display the classification report (optional)
)

# %% [markdown]
# ---

# %% [markdown]
# ### 5.3 Training and Evaluation for InceptionResNetV2

# %% [markdown]
# #### 5.3.1 Model Building and Compilation - InceptionResNetV2

# %%
model_name = 'InceptionResNetV2' 

# Define the number of layers to unfreeze
unfreeze_layers = 10

#Initialize the model using the build_model function.
model = build_model(
    model_name=model_name,
    input_shape=in_shape_299,
    num_classes=NUM_CLASSES,
    unfreeze_last_layers_count=unfreeze_layers  
)

# %% [markdown]
# #### 5.3.2 Training - InceptionResNetV2

# %%
# %%time

# Calling the train_model_and_save function
model, history = train_model_and_save(
    model=model,
    train_data=train_gen_299x299,   # The subset of training data
    val_data=valid_gen_299x299,       # The subset of validation data
    epochs=EPOCHS,                 
    batch_size=BATCH_SIZE,        
    class_weight_dict=class_weight_dict,  # Apply class weights 
    learning_rate=LEARNING_RATE,  
    model_name=model_name,          # The model name for saving
    save_model_dir= MODEL_DIR,      # Directory to save the model and checkpoints
    step_name = STEP_NAME         # The current step name (e.g., 'Step2', 'Step3') for proper file naming
)

# %% [markdown]
# #### 5.3.3 Evaluation - InceptionResNetV2

# %%
# Call the evaluate_model function 
evaluate_model(
    model=model,
    test_data=valid_gen_299x299,  # The test data generator or dataset
    history=history,              # Pass the training history to display learning curves
    model_name=model_name,      # Name of the model
    class_names=class_names,      # List of class names (0-26)
    plot_curve=True,              # Display the learning curve (optional)
    plot_cm=True,                 # Display the confusion matrix (optional)
    report=True                   # Display the classification report (optional)
)

# %% [markdown]
# ---

# %% [markdown]
# ### 5.4 Training and Evaluation for Xception

# %% [markdown]
# #### 5.4.1 Model Building and Compilation - Xception

# %%
model_name = 'Xception' 

# Define the number of layers to unfreeze
unfreeze_layers = 10

#Initialize the model using the build_model function.
model = build_model(
    model_name=model_name,
    input_shape=in_shape_299,
    num_classes=NUM_CLASSES,
    unfreeze_last_layers_count=unfreeze_layers  
)

# %% [markdown]
# #### 5.4.2 Training - Xception

# %%
# %%time

LEARNING_RATE = 0.000106

# Calling the train_model_and_save function 
model, history = train_model_and_save(
    model=model,
    train_data=train_gen_299x299,   # The subset of training data
    val_data=valid_gen_299x299,       # The subset of validation data
    epochs=EPOCHS,                  
    batch_size=BATCH_SIZE,         
    class_weight_dict=class_weight_dict,  # Apply class weights 
    learning_rate=LEARNING_RATE,         
    model_name=model_name,          # The model name for saving
    save_model_dir= MODEL_DIR,      # Directory to save the model and checkpoints
    step_name = STEP_NAME         # The current step name (e.g., 'Step2', 'Step3') for proper file naming
)
# Out:
# Epoch 1/40
# 1062/1062 [==============================] - ETA: 0s - loss: 8.4445 - accuracy: 0.3322
# Epoch 1: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 321s 1s/step
# Epoch 1: val_f1_score improved, saving model to ..\..\..\models\image\final_training\Step5_Xception_checkpoint.h5
# 1062/1062 [==============================] - 1985s 2s/step - loss: 8.4445 - accuracy: 0.3322 - val_loss: 4.4404 - val_accuracy: 0.4395 - val_f1_score: 0.0486
# Epoch 2/40
# 1062/1062 [==============================] - ETA: 0s - loss: 4.1613 - accuracy: 0.4526
# Epoch 2: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 313s 1s/step
# 1062/1062 [==============================] - 1901s 2s/step - loss: 4.1613 - accuracy: 0.4526 - val_loss: 2.8396 - val_accuracy: 0.4765 - val_f1_score: 0.0447
# Epoch 3/40
# 1062/1062 [==============================] - ETA: 0s - loss: 3.1014 - accuracy: 0.4946
# Epoch 3: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 317s 1s/step
# Epoch 3: val_f1_score improved, saving model to ..\..\..\models\image\final_training\Step5_Xception_checkpoint.h5
# 1062/1062 [==============================] - 1935s 2s/step - loss: 3.1014 - accuracy: 0.4946 - val_loss: 2.2140 - val_accuracy: 0.5258 - val_f1_score: 0.0525
# Epoch 4/40
# 1062/1062 [==============================] - ETA: 0s - loss: 2.6490 - accuracy: 0.5250
# Epoch 4: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 316s 1s/step
# 1062/1062 [==============================] - 1917s 2s/step - loss: 2.6490 - accuracy: 0.5250 - val_loss: 2.0187 - val_accuracy: 0.5283 - val_f1_score: 0.0477
# Epoch 5/40
# 1062/1062 [==============================] - ETA: 0s - loss: 2.4062 - accuracy: 0.5466
# Epoch 5: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 314s 1s/step
# 1062/1062 [==============================] - 1911s 2s/step - loss: 2.4062 - accuracy: 0.5466 - val_loss: 1.8929 - val_accuracy: 0.5423 - val_f1_score: 0.0522
# Epoch 6/40
# 1062/1062 [==============================] - ETA: 0s - loss: 2.2501 - accuracy: 0.5617
# Epoch 6: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 320s 1s/step
# 1062/1062 [==============================] - 1909s 2s/step - loss: 2.2501 - accuracy: 0.5617 - val_loss: 1.8361 - val_accuracy: 0.5494 - val_f1_score: 0.0512
# Epoch 7/40
# 1062/1062 [==============================] - ETA: 0s - loss: 2.1176 - accuracy: 0.5798
# Epoch 7: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 318s 1s/step
# 1062/1062 [==============================] - 1914s 2s/step - loss: 2.1176 - accuracy: 0.5798 - val_loss: 1.7782 - val_accuracy: 0.5581 - val_f1_score: 0.0489
# Epoch 8/40
# 1062/1062 [==============================] - ETA: 0s - loss: 2.0367 - accuracy: 0.5905
# Epoch 8: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 316s 1s/step
# 1062/1062 [==============================] - 1909s 2s/step - loss: 2.0367 - accuracy: 0.5905 - val_loss: 1.7907 - val_accuracy: 0.5443 - val_f1_score: 0.0494
# Epoch 9/40
# 1062/1062 [==============================] - ETA: 0s - loss: 1.9490 - accuracy: 0.6028
# Epoch 9: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 330s 1s/step
# 1062/1062 [==============================] - 1929s 2s/step - loss: 1.9490 - accuracy: 0.6028 - val_loss: 1.7574 - val_accuracy: 0.5588 - val_f1_score: 0.0498
# Epoch 10/40
# 1062/1062 [==============================] - ETA: 0s - loss: 1.8790 - accuracy: 0.6136
# Epoch 10: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 316s 1s/step
# 1062/1062 [==============================] - 1934s 2s/step - loss: 1.8790 - accuracy: 0.6136 - val_loss: 1.6869 - val_accuracy: 0.5765 - val_f1_score: 0.0497
# Epoch 11/40
# 1062/1062 [==============================] - ETA: 0s - loss: 1.8173 - accuracy: 0.6211
# Epoch 11: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 325s 1s/step
# Epoch 11: val_f1_score improved, saving model to ..\..\..\models\image\final_training\Step5_Xception_checkpoint.h5
# 1062/1062 [==============================] - 1907s 2s/step - loss: 1.8173 - accuracy: 0.6211 - val_loss: 1.6595 - val_accuracy: 0.5852 - val_f1_score: 0.0525
# Epoch 12/40
# 1062/1062 [==============================] - ETA: 0s - loss: 1.7566 - accuracy: 0.6329
# Epoch 12: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 319s 1s/step
# 1062/1062 [==============================] - 1931s 2s/step - loss: 1.7566 - accuracy: 0.6329 - val_loss: 1.6621 - val_accuracy: 0.5847 - val_f1_score: 0.0515
# Epoch 13/40
# 1062/1062 [==============================] - ETA: 0s - loss: 1.7056 - accuracy: 0.6386
# Epoch 13: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 319s 1s/step
# 1062/1062 [==============================] - 1904s 2s/step - loss: 1.7056 - accuracy: 0.6386 - val_loss: 1.6939 - val_accuracy: 0.5753 - val_f1_score: 0.0490
# Epoch 14/40
# 1062/1062 [==============================] - ETA: 0s - loss: 1.6527 - accuracy: 0.6476
# Epoch 14: Evaluating model performance on validation data... Computing weighted F1 score.
# 266/266 [==============================] - 312s 1s/step
# 1062/1062 [==============================] - 1906s 2s/step - loss: 1.6527 - accuracy: 0.6476 - val_loss: 1.6536 - val_accuracy: 0.5893 - val_f1_score: 0.0515
# Epoch 15/40
#   66/1062 [>.............................] - ETA: 20:07 - loss: 1.5700 - accuracy: 0.6674

# %% [markdown]
# #### 5.4.3 Evaluation - Xception

# %%
# Call the evaluate_model function 
evaluate_model(
    model=model,
    test_data=valid_gen_299x299,  # The test data generator or dataset
    history=history,              # Pass the training history to display learning curves
    model_name=model_name,      # Name of the model
    class_names=class_names,      # List of class names (0-26)
    plot_curve=True,              # Display the learning curve (optional)
    plot_cm=True,                 # Display the confusion matrix (optional)
    report=True                   # Display the classification report (optional)
)

# %% [markdown]
# ---

# %% [markdown]
# ### 5.5 Training and Evaluation for InceptionV3

# %% [markdown]
# #### 5.5.1 Model Building and Compilation - InceptionV3

# %%
model_name = 'InceptionV3' 

# Define the number of layers to unfreeze
unfreeze_layers = 10

#Initialize the model using the build_model function.
model = build_model(
    model_name=model_name,
    input_shape=in_shape_299,
    num_classes=NUM_CLASSES,
    unfreeze_last_layers_count=unfreeze_layers  
)

# %% [markdown]
# #### 5.5.2 Training - InceptionV3

# %%
# %%time

LEARNING_RATE = 0.000225

# Calling the train_model_and_save function 
model, history = train_model_and_save(
    model=model,
    train_data=train_gen_299x299,   # The subset of training data
    val_data=valid_gen_299x299,       # The subset of validation data
    epochs=EPOCHS,                  
    batch_size=BATCH_SIZE,         
    class_weight_dict=class_weight_dict,  # Apply class weights 
    learning_rate=LEARNING_RATE,         
    model_name=model_name,          # The model name for saving
    save_model_dir= MODEL_DIR,      # Directory to save the model and checkpoints
    step_name = STEP_NAME         # The current step name (e.g., 'Step2', 'Step3') for proper file naming
)

# %% [markdown]
# #### 5.5.3 Evaluation - InceptionV3

# %%
# Call the evaluate_model function 
evaluate_model(
    model=model,
    test_data=valid_gen_299x299,  # The test data generator or dataset
    history=history,              # Pass the training history to display learning curves
    model_name=model_name,      # Name of the model
    class_names=class_names,      # List of class names (0-26)
    plot_curve=True,              # Display the learning curve (optional)
    plot_cm=True,                 # Display the confusion matrix (optional)
    report=True                   # Display the classification report (optional)
)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 6. Results and Next Steps
# 🔜 Transition to: `19_Image_Fine_Tuning.ipynb`
#
# Unfreeze top layers for fine-tuning.
# Adjust learning rates for better convergence.
# Test advanced optimizations (batch normalization, dropout tuning...)
