# %% [markdown]
# # InceptionV3 : Images - Iteration #4_1(Data Augementation)

# %% [markdown]
# img_rows = 299 <br>
# img_cols = 299 <br>
# batch_size = 64 <br>
# epochs = 40 <br>
# Train set size = 67933 <br>
# Valid set size = 16983 <br>
# Data augmentation  <br>
# No unfreezing of base model layers <br>

# %% [markdown]
# **<u>Results</u>**

# %% [markdown]
# Accuracy : 0.58 <br>
# F1 score weighted : 0.56

# %% [markdown]
# **Import packages**

# %%
import os
import glob
import pandas as pd
import numpy as np
import cv2
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from tqdm.notebook import tqdm_notebook
import re
tqdm_notebook.pandas()
import tensorflow as tf
#from tensorflow import keras
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.efficientnet import EfficientNetB7
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn import metrics
import itertools
import pickle
from joblib import dump, load

# %% [markdown]
# # Iteration #4 - InceptionV3

# %% [markdown]
# ***Read DataFrame from saved pickele file - image Train set***

# %%
#Load df of images already resized on 256 x 256 
#df_train_im = pd.read_pickle("./saves/df_save/df_train_combined_19102021.pkl")

#Load df of images with org size 500 x 500
df_train_im = pd.read_pickle("./saves/df_save/df_train_combined_ORG_im_size_02122021.pkl")

# %%
df_train_im.head()
# Out:
#                                          designation  \
# 0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#    prdtypecode                                imagePath
# 0           10  image_1263597046_product_3804725264.jpg
# 1         2280   image_1008141237_product_436067568.jpg
# 2           50    image_938777978_product_201115110.jpg
# 3         1280     image_457047496_product_50418756.jpg
# 4         2705   image_1077757786_product_278535884.jpg

# %%
display(df_train_im.shape)
# Out:
# (84916, 6)

# %% [markdown]
# ***Create Dataframe containing  product classes and their associated labels***

# %%
#Dictionary of prdtypecode and their corresponding categories
dict_prdtypecode = {"prdtypecode" : [50, 2705, 2522, 2582, 1560, 1281, 1920, 1280, 1140, 1300, 2060, 2583,
                                     60, 1320, 2280, 1302, 2220, 40, 2905, 2585, 1940, 1160, 1301, 10, 1180,
                                     2403, 2462],                 
            
                    "Label" : ["video games accessories", "books", "stationery", "kitchen and garden", 
                               "interior furniture and bedding", "board games", "interior accessories",
                               "toys for children","goodies", "remote controlled models", "decoration interior",
                               "piscine spa","games and consoles", "early childhood", "magazines", "kids toys",
                               "supplies for domestic animals", "imported video games", "online distribution of video games",
                               "gardening and DIY","Food","playing cards", "accessories children", "adult books",
                               "figurines_wargames", "children books",
                                "games"]
                   }
df_class = pd.DataFrame(data=dict_prdtypecode)
df_class
# Out:
#     prdtypecode                               Label
# 0            50             video games accessories
# 1          2705                               books
# 2          2522                          stationery
# 3          2582                  kitchen and garden
# 4          1560      interior furniture and bedding
# 5          1281                         board games
# 6          1920                interior accessories
# 7          1280                   toys for children
# 8          1140                             goodies
# 9          1300            remote controlled models
# 10         2060                 decoration interior
# 11         2583                         piscine spa
# 12           60                  games and consoles
# 13         1320                     early childhood
# 14         2280                           magazines
# 15         1302                           kids toys
# 16         2220       supplies for domestic animals
# 17           40                imported video games
# 18         2905  online distribution of video games
# 19         2585                   gardening and DIY
# 20         1940                                Food
# 21         1160                       playing cards
# 22         1301                accessories children
# 23           10                         adult books
# 24         1180                  figurines_wargames
# 25         2403                      children books
# 26         2462                               games

# %%
# Crate DF containing prdtypecode , categories and corresponding class used by model
df_class = df_class.sort_values(by = 'prdtypecode', ascending = True)
df_class['target_prdtypecode'] = [i for i in range(27)]
df_class
# Out:
#     prdtypecode                               Label  target_prdtypecode
# 23           10                         adult books                   0
# 17           40                imported video games                   1
# 0            50             video games accessories                   2
# 12           60                  games and consoles                   3
# 8          1140                             goodies                   4
# 21         1160                       playing cards                   5
# 24         1180                  figurines_wargames                   6
# 7          1280                   toys for children                   7
# 5          1281                         board games                   8
# 9          1300            remote controlled models                   9
# 22         1301                accessories children                  10
# 15         1302                           kids toys                  11
# 13         1320                     early childhood                  12
# 4          1560      interior furniture and bedding                  13
# 6          1920                interior accessories                  14
# 20         1940                                Food                  15
# 10         2060                 decoration interior                  16
# 16         2220       supplies for domestic animals                  17
# 14         2280                           magazines                  18
# 25         2403                      children books                  19
# 26         2462                               games                  20
# 2          2522                          stationery                  21
# 3          2582                  kitchen and garden                  22
# 11         2583                         piscine spa                  23
# 19         2585                   gardening and DIY                  24
# 1          2705                               books                  25
# 18         2905  online distribution of video games                  26

# %% [markdown]
# ***Change the 27 product codes to 0 to 26***

# %%
df_train_im.replace({'prdtypecode':{10:0,
                                    40:1,
                                    50:2,
                                    60:3,
                                    1140:4,
                                    1160:5,
                                    1180:6,
                                    1280:7,
                                    1281:8,
                                    1300:9                                    
                                    }}, inplace = True)

df_train_im.replace({'prdtypecode':{1301:10,
                                    1302:11,
                                    1320:12,
                                    1560:13,
                                    1920:14,
                                    1940:15,
                                    2060:16,
                                    2220:17,
                                    2280:18,
                                    2403:19,
                                    2462:20,
                                    2522:21,
                                    2582:22,
                                    2583:23,
                                    2585:24,
                                    2705:25,
                                    2905:26
                                    }}, inplace = True)

# %%
display(df_train_im["prdtypecode"].unique())
# Out:
# array([ 0, 18,  2,  7, 25, 21, 22, 13,  8, 14, 19,  4, 23,  6,  9, 20,  5,
#        16,  1,  3, 12, 11, 17, 26, 24, 15, 10], dtype=int64)

# %% [markdown]
#  ***Convert product code to string type***

# %%
df_train_im["prdtypecode"] = df_train_im["prdtypecode"].astype(str)

# %%
unique, counts = np.unique(df_train_im["prdtypecode"], return_counts=True)
dict(zip(unique, counts))
# Out:
# {'10': 3116,
#  '1140': 2671,
#  '1160': 3953,
#  '1180': 764,
#  '1280': 4870,
#  '1281': 2070,
#  '1300': 5045,
#  '1301': 807,
#  '1302': 2491,
#  '1320': 3241,
#  '1560': 5073,
#  '1920': 4303,
#  '1940': 803,
#  '2060': 4993,
#  '2220': 824,
#  '2280': 4760,
#  '2403': 4774,
#  '2462': 1421,
#  '2522': 4989,
#  '2582': 2589,
#  '2583': 10209,
#  '2585': 2496,
#  '2705': 2761,
#  '2905': 872,
#  '40': 2508,
#  '50': 1681,
#  '60': 832}

# %% [markdown]
#  ***Split Train Set***

# %%
# Split Train set 
X_train_im, X_test_im = train_test_split(df_train_im, train_size=0.8, random_state=1234)

# %%
display(X_train_im.shape)
display(X_test_im.shape)
# Out:
# (67932, 6)
# (16984, 6)

# %% [markdown]
# ***Data Generator***

# %%
img_rows = 299
img_cols = 299
batch_size = 64
epochs = 40

# Directory of images already resized on 256 x 256 
#images_dir_train = './data/images/all/image_train_resized/'
#images_dir_train = 'E:/WorkSpace_DataScience_E/Rakuten_Projet_Local/My_WS/data/images/all/image_train_resized/'

# Directory of images org resize 500 x 500
images_dir_train = './data/images/all/image_train/'
#images_dir_train = 'E:/WorkSpace_DataScience_E/Rakuten_Projet_Local/My_WS/data/images/all/image_train/'

# %%
# %%time
#Générateur de données
train_datagen = ImageDataGenerator(rescale = 1/255,
                                  shear_range=0.2,
                                  rotation_range = 45,
                                  width_shift_range = 0.1,
                                  height_shift_range = 0.1,
                                  zoom_range = 0.2,
                                  horizontal_flip = True,
                                  vertical_flip = True
                                  #validation_split = 0.2
                                )
# Out:
# Wall time: 0 ns

# %%
# %%time
valid_datagen = ImageDataGenerator(rescale=1./255)
# Out:
# Wall time: 0 ns

# %%
# %%time

#Itérateur 
train_generator = train_datagen.flow_from_dataframe(dataframe = X_train_im,
                                              directory = images_dir_train,
                                              as_ext = True,
                                              x_col = 'imagePath',
                                              y_col = 'prdtypecode',  #target data                                            
                                              class_mode = 'sparse',                                             
                                              target_size = (img_rows , img_cols), # default 256 x 256                                             
                                              batch_size = batch_size,                                             
                                              shuffle = True  # défault
                                              #subset = 'training'
                                             )
# Out:
# Found 67932 validated image filenames belonging to 27 classes.
# Wall time: 5.3 s

# %%
# %%time
# validation_split the validation batches ca be retrieved by specifying the subset as validation.
valid_generator = valid_datagen.flow_from_dataframe(dataframe = X_test_im, 
                                              directory = images_dir_train,
                                              as_ext = True,
                                              x_col = 'imagePath',
                                              y_col = 'prdtypecode',  #target data                                            
                                              class_mode = 'sparse',                                        
                                              target_size = (img_rows , img_cols), # default 256 x 256                                         
                                              batch_size = batch_size, 
                                              shuffle = False
                                              #subset  = 'validation'
                                             )
# Out:
# Found 16984 validated image filenames belonging to 27 classes.
# Wall time: 1.15 s

# %% [markdown]
#  ***InceptionV3 Implementation***

# %%
# %%time
# Chargement du modèle InceptionV3
inceptionV3  = InceptionV3(weights='imagenet', include_top = False, input_shape=(img_rows,img_rows,3))

# Bloquage du blackbone
for layer in inceptionV3.layers:
    layer.trainable = False
    
model = Sequential()
model.add(inceptionV3)
# Ajout des couche de classification 
model.add(GlobalAveragePooling2D()) 
model.add(Dense(units = 1024,activation='relu'))

model.add(Dropout(rate = 0.2))
model.add(Dense(units = 512, activation='relu'))

model.add(Dropout(rate = 0.2))
#model.add(Dense(units = 27, activation='softmax'))
model.add(Dense(units = 27, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 27)                13851
# =================================================================
# Total params: 24,439,611
# Trainable params: 2,636,827
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Wall time: 3.4 s

# %% [markdown]
#  ***Compilation***

# %%
# %%time
# Compilation
model.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer='adam',                 # algorithme de descente de gradient
              metrics=['accuracy'])             # métrique d'évaluation
# Out:
# Wall time: 8.98 ms

# %% [markdown]
# ***Callbacks***

# %%
# %%time
path = './saves/InceptionV3/Iteration_4/'
file_name = 'checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5'

#Sauvegarder les meilleurs poids du modèle au cours de l'entraînement :
checkpoint = ModelCheckpoint(filepath = path + file_name , 
                             monitor ='val_accuracy',
                             verbose = 1,
                             save_best_only = True, # (pour que le meilleur modèle ne soit pas écrasé)
                             save_weights_only = False,
                             mode ='max', #(permet de préciser si la métrique doit croître ou décroitre : ici on choisit 'min'
                                           #car la métrique est une perte à minimiser)
                             save_freq='epoch')
#Arrêter l'entraînement si le modèle n'évolue plus (très pratique pour ne pas gérer le
#nombre d'epoch) :
early = EarlyStopping(monitor='val_loss',
                      min_delta = 0,
                      patience = 10, #(nombre d'epochs à attendre avant d'arrêter l'entraînement
                      restore_best_weights = True,
                      verbose = 1,
                      mode = 'min')
# Out:
# Wall time: 0 ns

# %% [markdown]
#  ***Fit - train_generator***

# %%
step_size_Train = train_generator.n//train_generator.batch_size
step_size_Valid = valid_generator.n//valid_generator.batch_size
print('step_size_Train : ' , step_size_Train)
print('step_size_Valid  : ' , step_size_Valid)
# Out:
# step_size_Train :  1061
# step_size_Valid  :  265

# %%
# %%time
# Fit Train generator
history = model.fit(train_generator,                    
                    epochs = epochs,                   
                    steps_per_epoch = step_size_Train,
                    validation_data = valid_generator,
                    validation_steps = step_size_Valid,
                    callbacks=[checkpoint,early]                    
                    )
# Out:
# Epoch 1/40
# 1061/1061 [==============================] - 1170s 1s/step - loss: 1.9888 - accuracy: 0.4133 - val_loss: 1.7122 - val_accuracy: 0.4876
#
# Epoch 00001: val_accuracy improved from -inf to 0.48756, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 2/40
# 1061/1061 [==============================] - 1128s 1s/step - loss: 1.7576 - accuracy: 0.4747 - val_loss: 1.6600 - val_accuracy: 0.4991
#
# Epoch 00002: val_accuracy improved from 0.48756 to 0.49906, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 3/40
# 1061/1061 [==============================] - 1117s 1s/step - loss: 1.6808 - accuracy: 0.4990 - val_loss: 1.5993 - val_accuracy: 0.5181
#
# Epoch 00003: val_accuracy improved from 0.49906 to 0.51810, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 4/40
# 1061/1061 [==============================] - 1065s 1s/step - loss: 1.6310 - accuracy: 0.5110 - val_loss: 1.5591 - val_accuracy: 0.5301
#
# Epoch 00004: val_accuracy improved from 0.51810 to 0.53007, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 5/40
# 1061/1061 [==============================] - 1010s 952ms/step - loss: 1.5908 - accuracy: 0.5222 - val_loss: 1.5106 - val_accuracy: 0.5479
#
# Epoch 00005: val_accuracy improved from 0.53007 to 0.54788, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 6/40
# 1061/1061 [==============================] - 1012s 954ms/step - loss: 1.5688 - accuracy: 0.5277 - val_loss: 1.5247 - val_accuracy: 0.5393
#
# Epoch 00006: val_accuracy did not improve from 0.54788
# Epoch 7/40
# 1061/1061 [==============================] - 1010s 952ms/step - loss: 1.5478 - accuracy: 0.5341 - val_loss: 1.5061 - val_accuracy: 0.5489
#
# Epoch 00007: val_accuracy improved from 0.54788 to 0.54888, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 8/40
# 1061/1061 [==============================] - 1018s 959ms/step - loss: 1.5276 - accuracy: 0.5365 - val_loss: 1.5003 - val_accuracy: 0.5516
#
# Epoch 00008: val_accuracy improved from 0.54888 to 0.55159, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 9/40
# 1061/1061 [==============================] - 1078s 1s/step - loss: 1.5057 - accuracy: 0.5447 - val_loss: 1.4830 - val_accuracy: 0.5550
#
# Epoch 00009: val_accuracy improved from 0.55159 to 0.55495, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 10/40
# 1061/1061 [==============================] - 1084s 1s/step - loss: 1.4966 - accuracy: 0.5466 - val_loss: 1.4755 - val_accuracy: 0.5513
#
# Epoch 00010: val_accuracy did not improve from 0.55495
# Epoch 11/40
# 1061/1061 [==============================] - 1080s 1s/step - loss: 1.4804 - accuracy: 0.5504 - val_loss: 1.4802 - val_accuracy: 0.5527
#
# Epoch 00011: val_accuracy did not improve from 0.55495
# Epoch 12/40
# 1061/1061 [==============================] - 1087s 1s/step - loss: 1.4728 - accuracy: 0.5527 - val_loss: 1.4577 - val_accuracy: 0.5613
#
# Epoch 00012: val_accuracy improved from 0.55495 to 0.56126, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 13/40
# 1061/1061 [==============================] - 1091s 1s/step - loss: 1.4597 - accuracy: 0.5564 - val_loss: 1.4715 - val_accuracy: 0.5564
#
# Epoch 00013: val_accuracy did not improve from 0.56126
# Epoch 14/40
# 1061/1061 [==============================] - 1072s 1s/step - loss: 1.4465 - accuracy: 0.5588 - val_loss: 1.4710 - val_accuracy: 0.5554
#
# Epoch 00014: val_accuracy did not improve from 0.56126
# Epoch 15/40
# 1061/1061 [==============================] - 1671s 2s/step - loss: 1.4428 - accuracy: 0.5622 - val_loss: 1.4717 - val_accuracy: 0.5603
#
# Epoch 00015: val_accuracy did not improve from 0.56126
# Epoch 16/40
# 1061/1061 [==============================] - 1572s 1s/step - loss: 1.4338 - accuracy: 0.5640 - val_loss: 1.4719 - val_accuracy: 0.5601
#
# Epoch 00016: val_accuracy did not improve from 0.56126
# Epoch 17/40
# 1061/1061 [==============================] - 1078s 1s/step - loss: 1.4275 - accuracy: 0.5663 - val_loss: 1.4514 - val_accuracy: 0.5615
#
# Epoch 00017: val_accuracy improved from 0.56126 to 0.56150, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 18/40
# 1061/1061 [==============================] - 1080s 1s/step - loss: 1.4160 - accuracy: 0.5689 - val_loss: 1.4712 - val_accuracy: 0.5604
#
# Epoch 00018: val_accuracy did not improve from 0.56150
# Epoch 19/40
# 1061/1061 [==============================] - 1084s 1s/step - loss: 1.4119 - accuracy: 0.5683 - val_loss: 1.4461 - val_accuracy: 0.5605
#
# Epoch 00019: val_accuracy did not improve from 0.56150
# Epoch 20/40
# 1061/1061 [==============================] - 1098s 1s/step - loss: 1.3995 - accuracy: 0.5724 - val_loss: 1.4559 - val_accuracy: 0.5621
#
# Epoch 00020: val_accuracy improved from 0.56150 to 0.56209, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 21/40
# 1061/1061 [==============================] - 1082s 1s/step - loss: 1.3957 - accuracy: 0.5709 - val_loss: 1.4408 - val_accuracy: 0.5670
#
# Epoch 00021: val_accuracy improved from 0.56209 to 0.56698, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 22/40
# 1061/1061 [==============================] - 1086s 1s/step - loss: 1.3936 - accuracy: 0.5736 - val_loss: 1.4390 - val_accuracy: 0.5677
#
# Epoch 00022: val_accuracy improved from 0.56698 to 0.56775, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 23/40
# 1061/1061 [==============================] - 1081s 1s/step - loss: 1.3847 - accuracy: 0.5756 - val_loss: 1.4220 - val_accuracy: 0.5744
#
# Epoch 00023: val_accuracy improved from 0.56775 to 0.57435, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 24/40
# 1061/1061 [==============================] - 1083s 1s/step - loss: 1.3778 - accuracy: 0.5770 - val_loss: 1.4084 - val_accuracy: 0.5795
#
# Epoch 00024: val_accuracy improved from 0.57435 to 0.57948, saving model to ./saves/InceptionV3/Iteration_4\checkpoint_InceptionV3_03122021_Shape-299x299_40Epochs.h5
# Epoch 25/40
# 1061/1061 [==============================] - 1086s 1s/step - loss: 1.3746 - accuracy: 0.5772 - val_loss: 1.4360 - val_accuracy: 0.5671
#
# Epoch 00025: val_accuracy did not improve from 0.57948
# Epoch 26/40
# 1061/1061 [==============================] - 23189s 22s/step - loss: 1.3697 - accuracy: 0.5802 - val_loss: 1.4325 - val_accuracy: 0.5701
#
# Epoch 00026: val_accuracy did not improve from 0.57948
# Epoch 27/40
# 1061/1061 [==============================] - 1033s 974ms/step - loss: 1.3576 - accuracy: 0.5835 - val_loss: 1.4273 - val_accuracy: 0.5731
#
# Epoch 00027: val_accuracy did not improve from 0.57948
# Epoch 28/40
# 1061/1061 [==============================] - 1116s 1s/step - loss: 1.3586 - accuracy: 0.5842 - val_loss: 1.4223 - val_accuracy: 0.5724
#
# Epoch 00028: val_accuracy did not improve from 0.57948
# Epoch 29/40
# 1061/1061 [==============================] - 1031s 972ms/step - loss: 1.3557 - accuracy: 0.5852 - val_loss: 1.4227 - val_accuracy: 0.5737
#
# Epoch 00029: val_accuracy did not improve from 0.57948
# Epoch 30/40
# 1061/1061 [==============================] - 1013s 955ms/step - loss: 1.3430 - accuracy: 0.5876 - val_loss: 1.4428 - val_accuracy: 0.5699
#
# Epoch 00030: val_accuracy did not improve from 0.57948
# Epoch 31/40
# 1061/1061 [==============================] - 1013s 955ms/step - loss: 1.3461 - accuracy: 0.5859 - val_loss: 1.4268 - val_accuracy: 0.5655
#
# Epoch 00031: val_accuracy did not improve from 0.57948
# Epoch 32/40
# 1061/1061 [==============================] - 1008s 950ms/step - loss: 1.3428 - accuracy: 0.5892 - val_loss: 1.4269 - val_accuracy: 0.5698
#
# Epoch 00032: val_accuracy did not improve from 0.57948
# Epoch 33/40
# 1061/1061 [==============================] - 1010s 952ms/step - loss: 1.3397 - accuracy: 0.5888 - val_loss: 1.4377 - val_accuracy: 0.5732
#
# Epoch 00033: val_accuracy did not improve from 0.57948
# Epoch 34/40
# 1061/1061 [==============================] - 1010s 951ms/step - loss: 1.3397 - accuracy: 0.5895 - val_loss: 1.4244 - val_accuracy: 0.5746
#
# Epoch 00034: val_accuracy did not improve from 0.57948
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping
# Wall time: 16h 30min 57s

# %% [markdown]
# ***Save History results***

# %%
# Save History results
path = './saves/InceptionV3/Iteration_4/'
filename = 'history_InceptionV3_all_train_03122021_Shape-299x299_40Epochs'

# %%
#convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# history to json:  
hist_json_file = path + filename + '.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# history to csv: 
hist_csv_file = path + filename +'.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# history to pickle file
hist_df.to_pickle(path + filename +'.pkl')

# %% [markdown]
# ***Display Model loss , accuracy per epoch***

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model acc by epoch')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')
plt.show()

# %% [markdown]
#  ***Prediction - test_generator***

# %%
# %%time
#Prediction - Valid set
y_pred_proba = model.predict(valid_generator)

# l'argmax pour obtenir les classes prédites
y_pred_class = np.argmax(y_pred_proba,axis = 1).astype(int)

# To get classes from test generator
y_true = valid_generator.classes
# Out:
# Wall time: 1min 3s

# %% [markdown]
#  ***Evaluation - test_generator***

# %%
# %%time
#Get the accuracy score
valid_score = model.evaluate(valid_generator)
print("[INFO] Model metrics names:", model.metrics_names)
print("[INFO] Accuracy: {:.2f}%".format(valid_score[1] * 100)) 
print("[INFO] Loss: ",valid_score[0])
# Out:
# 266/266 [==============================] - 52s 196ms/step - loss: 1.4087 - accuracy: 0.5794
# [INFO] Model metrics names: ['loss', 'accuracy']
# [INFO] Accuracy: 57.94%
# [INFO] Loss:  1.4086648225784302
# Wall time: 52.7 s

# %%
f1_macro = f1_score(y_true, y_pred_class, average='macro')
print("[INFO] f1 score macro average: ",f1_macro)

f1_micro = f1_score(y_true, y_pred_class, average='micro')
print("[INFO] f1 score micro average: ",f1_micro)

f1_weighted = f1_score(y_true, y_pred_class, average='weighted')
print("[INFO] f1 score weighted average: ",f1_weighted)
# Out:
# [INFO] f1 score macro average:  0.5071917139520645
# [INFO] f1 score micro average:  0.5793688177107866
# [INFO] f1 score weighted average:  0.5646549076633793

# %%
#Confusion matrix
matrix = confusion_matrix(y_true, y_pred_class)
fig , ax = plt.subplots(figsize = (24,20))
ax.matshow(matrix, cmap = plt.cm.Oranges , alpha = 0.3)
for i in range(matrix.shape[0]):
    for j in range (matrix.shape[1]):
        ax.text (x = j , y= i, s= matrix[i,j], va = 'center', ha = 'center', size = 'xx-large')
        
plt.xlabel('predicted', fontsize = 18)
plt.ylabel('Acutals', fontsize = 18)
plt.title('Confusion Matrix', fontsize = 18)
plt.show()
#print(matrix)

# %%
print(metrics.classification_report(y_true, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.46      0.47       643
#            1       0.44      0.42      0.43       503
#            2       0.72      0.54      0.61       162
#            3       0.49      0.39      0.44       514
#            4       0.64      0.36      0.46       664
#            5       0.60      0.53      0.56       993
#            6       0.78      0.79      0.79       832
#            7       0.51      0.61      0.56       159
#            8       0.40      0.56      0.47       970
#            9       0.46      0.19      0.27       190
#           10       0.58      0.68      0.62       911
#           11       0.63      0.54      0.58       961
#           12       0.49      0.19      0.28       319
#           13       0.87      0.29      0.43       301
#           14       0.65      0.65      0.65      1011
#           15       0.58      0.28      0.38       533
#           16       0.66      0.86      0.75      2083
#           17       0.47      0.35      0.40       468
#           18       0.53      0.77      0.62       557
#           19       0.45      0.27      0.34       146
#           20       0.62      0.63      0.62       179
#           21       0.56      0.67      0.61       545
#           22       0.82      0.89      0.85       793
#           23       0.58      0.12      0.21       144
#           24       0.49      0.38      0.42      1002
#           25       0.30      0.22      0.26       408
#           26       0.51      0.78      0.61       993
#
#     accuracy                           0.58     16984
#    macro avg       0.57      0.50      0.51     16984
# weighted avg       0.58      0.58      0.56     16984

# %% [markdown]
#  ***Predict input image using trained model***

# %%
# Predict With Pre Trained

# Load an image
im_id = 250
#img_path ='./data/images/all/image_train_resized/'+ df_train_im['imagePath'][im_id]
img_path ='./data/images/all/image_train/'+ df_train_im['imagePath'][im_id]

img = image.load_img(img_path,target_size=(224, 224))
plt.figure(figsize=(6,4))
plt.imshow(img)
plt.title("class: " + str(df_train_im['prdtypecode'][im_id]))
plt.xticks([])
plt.yticks([])
#plt.axis('off')
plt.show();

# %%
im = cv2.resize(cv2.imread(img_path), (299, 299))
im = np.expand_dims(im, axis=0)

# %%
out = model.predict(im)
print("------------------Predicted Class and Label ------------------------------")
print("target class(used by model) :", np.argmax(out))
print("\n"  ,df_class[df_class['target_prdtypecode'] == np.argmax(out)][['prdtypecode', 'Label']].to_string(index=False)) 

prd_code = df_train_im['prdtypecode'][im_id]

print("\n\n------------------Real Class and Label ------------------------------")
print("target class(used by model): " ,  df_class[df_class['target_prdtypecode'] == int(prd_code)]['target_prdtypecode'].to_string(index=False))
print("\n"  ,df_class[df_class['target_prdtypecode'] == int(prd_code)][['prdtypecode', 'Label']].to_string(index=False))
# Out:
# ------------------Predicted Class and Label ------------------------------
# target class(used by model) : 15
#
#   prdtypecode Label
#         1940  Food
#
#
# ------------------Real Class and Label ------------------------------
# target class(used by model):  14
#
#   prdtypecode                Label
#         1920 interior accessories

# %% [markdown]
#  ***Save InceptionV3 Model***

# %%
#Enregistrement du modèle
model.save("./saves/InceptionV3/Iteration_4/Model_InceptionV3_All_train_data_03122021_Shape-299x299_40Epochs.hdf5")
#The SavedModel and HDF5 file contains:
#the model's configuration (topology)
#the model's weights
#the model's optimizer's state (if any)

# %% [markdown]
#  ***Load InceptionV3 Model***

# %%
#Rechargement du modèle :
model = load_model('./saves/InceptionV3/Iteration_4/Model_InceptionV3_All_train_data_03122021_Shape-299x299_40Epochs.hdf5')
