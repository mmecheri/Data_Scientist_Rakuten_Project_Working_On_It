# %% [markdown]
# # InceptionV3 : Images - Iteration #3(Without Data Augementation)

# %% [markdown]
# img_rows = 299 <br>
# img_cols = 299 <br>
# batch_size = 64 <br>
# epochs = 50 <br>
# Train set size = 67933 <br>
# Valid set size = 16983 <br>
# <font color='red'>  optimizer= Adam(learning_rate= 1e-5) </font <br>

# %% [markdown]
# **<u>Results</u>**

# %% [markdown]
# Accuracy : 0.61<br>
# F1 score weighted : 0.60

# %% [markdown]
# **Import packages**

# %%
import os
import glob
import pandas as pd
import numpy as np
import cv2
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from tqdm.notebook import tqdm_notebook
import re
tqdm_notebook.pandas()
import tensorflow as tf
#from tensorflow import keras
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.efficientnet import EfficientNetB7
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn import metrics
import itertools
import pickle
from joblib import dump, load

# %% [markdown]
# # Iteration #4_3 - InceptionV3

# %% [markdown]
# ***Read DataFrame from saved pickele file - image Train set***

# %%
#Load df of images already resized on 256 x 256 
#df_train_im = pd.read_pickle("./saves/df_save/df_train_combined_19102021.pkl")

#Load df of images with org size 500 x 500
df_train_im = pd.read_pickle("./saves/df_save/df_train_combined_ORG_im_size_02122021.pkl")

# %%
df_train_im.head()
# Out:
#                                          designation  \
# 0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#    prdtypecode                                imagePath
# 0           10  image_1263597046_product_3804725264.jpg
# 1         2280   image_1008141237_product_436067568.jpg
# 2           50    image_938777978_product_201115110.jpg
# 3         1280     image_457047496_product_50418756.jpg
# 4         2705   image_1077757786_product_278535884.jpg

# %%
display(df_train_im.shape)
# Out:
# (84916, 6)

# %% [markdown]
# ***Create Dataframe containing  product classes and their associated labels***

# %%
#Dictionary of prdtypecode and their corresponding categories
dict_prdtypecode = {"prdtypecode" : [50, 2705, 2522, 2582, 1560, 1281, 1920, 1280, 1140, 1300, 2060, 2583,
                                     60, 1320, 2280, 1302, 2220, 40, 2905, 2585, 1940, 1160, 1301, 10, 1180,
                                     2403, 2462],                 
            
                    "Label" : ["video games accessories", "books", "stationery", "kitchen and garden", 
                               "interior furniture and bedding", "board games", "interior accessories",
                               "toys for children","goodies", "remote controlled models", "decoration interior",
                               "piscine spa","games and consoles", "early childhood", "magazines", "kids toys",
                               "supplies for domestic animals", "imported video games", "online distribution of video games",
                               "gardening and DIY","Food","playing cards", "accessories children", "adult books",
                               "figurines_wargames", "children books",
                                "games"]
                   }
df_class = pd.DataFrame(data=dict_prdtypecode)
df_class
# Out:
#     prdtypecode                               Label
# 0            50             video games accessories
# 1          2705                               books
# 2          2522                          stationery
# 3          2582                  kitchen and garden
# 4          1560      interior furniture and bedding
# 5          1281                         board games
# 6          1920                interior accessories
# 7          1280                   toys for children
# 8          1140                             goodies
# 9          1300            remote controlled models
# 10         2060                 decoration interior
# 11         2583                         piscine spa
# 12           60                  games and consoles
# 13         1320                     early childhood
# 14         2280                           magazines
# 15         1302                           kids toys
# 16         2220       supplies for domestic animals
# 17           40                imported video games
# 18         2905  online distribution of video games
# 19         2585                   gardening and DIY
# 20         1940                                Food
# 21         1160                       playing cards
# 22         1301                accessories children
# 23           10                         adult books
# 24         1180                  figurines_wargames
# 25         2403                      children books
# 26         2462                               games

# %%
# Crate DF containing prdtypecode , categories and corresponding class used by model
df_class = df_class.sort_values(by = 'prdtypecode', ascending = True)
df_class['target_prdtypecode'] = [i for i in range(27)]
df_class
# Out:
#     prdtypecode                               Label  target_prdtypecode
# 23           10                         adult books                   0
# 17           40                imported video games                   1
# 0            50             video games accessories                   2
# 12           60                  games and consoles                   3
# 8          1140                             goodies                   4
# 21         1160                       playing cards                   5
# 24         1180                  figurines_wargames                   6
# 7          1280                   toys for children                   7
# 5          1281                         board games                   8
# 9          1300            remote controlled models                   9
# 22         1301                accessories children                  10
# 15         1302                           kids toys                  11
# 13         1320                     early childhood                  12
# 4          1560      interior furniture and bedding                  13
# 6          1920                interior accessories                  14
# 20         1940                                Food                  15
# 10         2060                 decoration interior                  16
# 16         2220       supplies for domestic animals                  17
# 14         2280                           magazines                  18
# 25         2403                      children books                  19
# 26         2462                               games                  20
# 2          2522                          stationery                  21
# 3          2582                  kitchen and garden                  22
# 11         2583                         piscine spa                  23
# 19         2585                   gardening and DIY                  24
# 1          2705                               books                  25
# 18         2905  online distribution of video games                  26

# %% [markdown]
# ***Change the 27 product codes to 0 to 26***

# %%
df_train_im.replace({'prdtypecode':{10:0,
                                    40:1,
                                    50:2,
                                    60:3,
                                    1140:4,
                                    1160:5,
                                    1180:6,
                                    1280:7,
                                    1281:8,
                                    1300:9                                    
                                    }}, inplace = True)

df_train_im.replace({'prdtypecode':{1301:10,
                                    1302:11,
                                    1320:12,
                                    1560:13,
                                    1920:14,
                                    1940:15,
                                    2060:16,
                                    2220:17,
                                    2280:18,
                                    2403:19,
                                    2462:20,
                                    2522:21,
                                    2582:22,
                                    2583:23,
                                    2585:24,
                                    2705:25,
                                    2905:26
                                    }}, inplace = True)

# %%
display(df_train_im["prdtypecode"].unique())
# Out:
# array([ 0, 18,  2,  7, 25, 21, 22, 13,  8, 14, 19,  4, 23,  6,  9, 20,  5,
#        16,  1,  3, 12, 11, 17, 26, 24, 15, 10], dtype=int64)

# %% [markdown]
#  ***Convert product code to string type***

# %%
df_train_im["prdtypecode"] = df_train_im["prdtypecode"].astype(str)

# %%
unique, counts = np.unique(df_train_im["prdtypecode"], return_counts=True)
dict(zip(unique, counts))
# Out:
# {'0': 3116,
#  '1': 2508,
#  '10': 807,
#  '11': 2491,
#  '12': 3241,
#  '13': 5073,
#  '14': 4303,
#  '15': 803,
#  '16': 4993,
#  '17': 824,
#  '18': 4760,
#  '19': 4774,
#  '2': 1681,
#  '20': 1421,
#  '21': 4989,
#  '22': 2589,
#  '23': 10209,
#  '24': 2496,
#  '25': 2761,
#  '26': 872,
#  '3': 832,
#  '4': 2671,
#  '5': 3953,
#  '6': 764,
#  '7': 4870,
#  '8': 2070,
#  '9': 5045}

# %% [markdown]
#  ***Split Train Set***

# %%
# Split Train set 
#X_train_im, X_test_im = train_test_split(df_train_im, train_size=0.8, random_state=1234)

# %%
#display(X_train_im.shape)
#display(X_test_im.shape)

# %% [markdown]
# ***Data Generator***

# %%
# %%time
#Générateur de données
img_gen = ImageDataGenerator(rescale = 1/255, 
                             validation_split = 0.2)
# Out:
# Wall time: 0 ns

# %%
img_rows = 299
img_cols = 299
batch_size = 64
epochs = 50

# Directory of images already resized on 256 x 256 
#images_dir_train = './data/images/all/image_train_resized/'
#images_dir_train = 'E:/WorkSpace_DataScience_E/Rakuten_Projet_Local/My_WS/data/images/all/image_train_resized/'

# Directory of images org resize 500 x 500
images_dir_train = './data/images/all/image_train/'
#images_dir_train = 'E:/WorkSpace_DataScience_E/Rakuten_Projet_Local/My_WS/data/images/all/image_train/'

# %%
# %%time

#Itérateur 
train_generator = img_gen.flow_from_dataframe(dataframe = df_train_im,
                                              directory = images_dir_train,
                                              as_ext = True,
                                              x_col = 'imagePath',
                                              y_col = 'prdtypecode',  #target data                                            
                                              class_mode = 'sparse',                                             
                                              target_size = (img_rows , img_cols), # default 256 x 256                                             
                                              batch_size = batch_size,                                             
                                              shuffle = True, # défault
                                              subset = 'training'
                                             )
# Out:
# Found 67933 validated image filenames belonging to 27 classes.
# Wall time: 5.64 s

# %%
# %%time
# validation_split the validation batches ca be retrieved by specifying the subset as validation.
valid_generator = img_gen.flow_from_dataframe(dataframe = df_train_im, 
                                              directory = images_dir_train,
                                              as_ext = True,
                                              x_col = 'imagePath',
                                              y_col = 'prdtypecode',  #target data                                            
                                              class_mode = 'sparse',                                        
                                              target_size = (img_rows , img_cols), # default 256 x 256                                         
                                              batch_size = batch_size, 
                                              shuffle = False,
                                              subset  = 'validation'
                                             )
# Out:
# Found 16983 validated image filenames belonging to 27 classes.
# Wall time: 5.52 s

# %% [markdown]
#  ***InceptionV3 Implementation***

# %%
# %%time
# Chargement du modèle InceptionV3
inceptionV3  = InceptionV3(weights='imagenet', include_top = False, input_shape=(img_rows,img_rows,3))

# Bloquage du blackbone
for layer in inceptionV3.layers:
    layer.trainable = False
    
model = Sequential()
model.add(inceptionV3)
# Ajout des couche de classification
model.add(GlobalAveragePooling2D()) 
model.add(Dense(units = 1024,activation='relu'))

model.add(Dropout(rate = 0.2))
model.add(Dense(units = 512, activation='relu'))

model.add(Dropout(rate = 0.2))
#model.add(Dense(units = 27, activation='softmax'))
model.add(Dense(units = 27, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 8, 8, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 27)                13851
# =================================================================
# Total params: 24,439,611
# Trainable params: 2,636,827
# Non-trainable params: 21,802,784
# _________________________________________________________________
# Wall time: 2.04 s

# %% [markdown]
#  ***Compilation***

# %%
# %%time
# Compilation
model.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer= Adam(learning_rate= 1e-5) ,   #default lr = 0.001 # algorithme de descente de gradient
              metrics=['accuracy'])                    # métrique d'évaluation
# Out:
# Wall time: 9.49 ms

# %% [markdown]
# ***Callbacks***

# %%
# %%time
path = './saves/InceptionV3/Iteration_4_3/'
file_name = 'checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5'

#Sauvegarder les meilleurs poids du modèle au cours de l'entraînement :
checkpoint = ModelCheckpoint(filepath = path + file_name , 
                             monitor ='val_accuracy',
                             verbose = 1,
                             save_best_only = True, # (pour que le meilleur modèle ne soit pas écrasé)
                             save_weights_only = False,
                             mode ='max', #(permet de préciser si la métrique doit croître ou décroitre : ici on choisit 'min'
                                           #car la métrique est une perte à minimiser)
                             save_freq='epoch')
#Arrêter l'entraînement si le modèle n'évolue plus (très pratique pour ne pas gérer le
#nombre d'epoch) :
early = EarlyStopping(monitor='val_loss',
                      min_delta = 0,
                      patience = 10, #(nombre d'epochs à attendre avant d'arrêter l'entraînement
                      restore_best_weights = True,
                      verbose = 1,
                      mode = 'min')

lr_plateau = ReduceLROnPlateau(monitor = 'val_loss',
                              patience = 10,
                              verbose = 1,
                              mode='min'
                              )
# Out:
# Wall time: 0 ns

# %% [markdown]
#  ***Fit - train_generator***

# %%
step_size_Train = train_generator.n//train_generator.batch_size
step_size_Valid = valid_generator.n//valid_generator.batch_size
print('step_size_Train : ' , step_size_Train)
print('step_size_Valid  : ' , step_size_Valid)
# Out:
# step_size_Train :  1061
# step_size_Valid  :  265

# %%
# %%time
# Fit Train generator
history = model.fit(train_generator,                    
                    epochs = epochs,                   
                    steps_per_epoch = step_size_Train,
                    validation_data = valid_generator,
                    validation_steps = step_size_Valid,
                    callbacks=[checkpoint,early]
                    
                    )
# Out:
# Epoch 1/50
# 1061/1061 [==============================] - 376s 345ms/step - loss: 2.5325 - accuracy: 0.3076 - val_loss: 2.0185 - val_accuracy: 0.4360
#
# Epoch 00001: val_accuracy improved from -inf to 0.43603, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 2/50
# 1061/1061 [==============================] - 252s 237ms/step - loss: 1.9940 - accuracy: 0.4300 - val_loss: 1.7968 - val_accuracy: 0.4808
#
# Epoch 00002: val_accuracy improved from 0.43603 to 0.48078, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 3/50
# 1061/1061 [==============================] - 254s 239ms/step - loss: 1.8353 - accuracy: 0.4689 - val_loss: 1.7005 - val_accuracy: 0.5054
#
# Epoch 00003: val_accuracy improved from 0.48078 to 0.50542, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 4/50
# 1061/1061 [==============================] - 254s 239ms/step - loss: 1.7441 - accuracy: 0.4913 - val_loss: 1.6421 - val_accuracy: 0.5205
#
# Epoch 00004: val_accuracy improved from 0.50542 to 0.52052, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 5/50
# 1061/1061 [==============================] - 256s 241ms/step - loss: 1.6835 - accuracy: 0.5073 - val_loss: 1.6067 - val_accuracy: 0.5281
#
# Epoch 00005: val_accuracy improved from 0.52052 to 0.52812, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 6/50
# 1061/1061 [==============================] - 252s 237ms/step - loss: 1.6304 - accuracy: 0.5213 - val_loss: 1.5718 - val_accuracy: 0.5372
#
# Epoch 00006: val_accuracy improved from 0.52812 to 0.53721, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 7/50
# 1061/1061 [==============================] - 251s 236ms/step - loss: 1.5962 - accuracy: 0.5311 - val_loss: 1.5478 - val_accuracy: 0.5432
#
# Epoch 00007: val_accuracy improved from 0.53721 to 0.54322, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 8/50
# 1061/1061 [==============================] - 252s 238ms/step - loss: 1.5587 - accuracy: 0.5390 - val_loss: 1.5293 - val_accuracy: 0.5495
#
# Epoch 00008: val_accuracy improved from 0.54322 to 0.54953, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 9/50
# 1061/1061 [==============================] - 253s 238ms/step - loss: 1.5312 - accuracy: 0.5461 - val_loss: 1.5102 - val_accuracy: 0.5534
#
# Epoch 00009: val_accuracy improved from 0.54953 to 0.55342, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 10/50
# 1061/1061 [==============================] - 253s 238ms/step - loss: 1.5006 - accuracy: 0.5534 - val_loss: 1.4945 - val_accuracy: 0.5597
#
# Epoch 00010: val_accuracy improved from 0.55342 to 0.55973, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 11/50
# 1061/1061 [==============================] - 253s 239ms/step - loss: 1.4809 - accuracy: 0.5613 - val_loss: 1.4811 - val_accuracy: 0.5630
#
# Epoch 00011: val_accuracy improved from 0.55973 to 0.56303, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 12/50
# 1061/1061 [==============================] - 254s 240ms/step - loss: 1.4590 - accuracy: 0.5670 - val_loss: 1.4663 - val_accuracy: 0.5668
#
# Epoch 00012: val_accuracy improved from 0.56303 to 0.56680, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 13/50
# 1061/1061 [==============================] - 257s 243ms/step - loss: 1.4381 - accuracy: 0.5729 - val_loss: 1.4571 - val_accuracy: 0.5709
#
# Epoch 00013: val_accuracy improved from 0.56680 to 0.57087, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 14/50
# 1061/1061 [==============================] - 261s 246ms/step - loss: 1.4192 - accuracy: 0.5769 - val_loss: 1.4466 - val_accuracy: 0.5723
#
# Epoch 00014: val_accuracy improved from 0.57087 to 0.57229, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 15/50
# 1061/1061 [==============================] - 261s 246ms/step - loss: 1.4009 - accuracy: 0.5817 - val_loss: 1.4372 - val_accuracy: 0.5735
#
# Epoch 00015: val_accuracy improved from 0.57229 to 0.57347, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 16/50
# 1061/1061 [==============================] - 261s 246ms/step - loss: 1.3805 - accuracy: 0.5879 - val_loss: 1.4289 - val_accuracy: 0.5777
#
# Epoch 00016: val_accuracy improved from 0.57347 to 0.57771, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 17/50
# 1061/1061 [==============================] - 261s 246ms/step - loss: 1.3658 - accuracy: 0.5921 - val_loss: 1.4223 - val_accuracy: 0.5782
#
# Epoch 00017: val_accuracy improved from 0.57771 to 0.57818, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 18/50
# 1061/1061 [==============================] - 264s 248ms/step - loss: 1.3491 - accuracy: 0.5950 - val_loss: 1.4134 - val_accuracy: 0.5809
#
# Epoch 00018: val_accuracy improved from 0.57818 to 0.58090, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 19/50
# 1061/1061 [==============================] - 258s 244ms/step - loss: 1.3365 - accuracy: 0.6008 - val_loss: 1.4047 - val_accuracy: 0.5851
#
# Epoch 00019: val_accuracy improved from 0.58090 to 0.58508, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 20/50
# 1061/1061 [==============================] - 260s 245ms/step - loss: 1.3185 - accuracy: 0.6054 - val_loss: 1.4022 - val_accuracy: 0.5848
#
# Epoch 00020: val_accuracy did not improve from 0.58508
# Epoch 21/50
# 1061/1061 [==============================] - 258s 243ms/step - loss: 1.3061 - accuracy: 0.6075 - val_loss: 1.3964 - val_accuracy: 0.5844
#
# Epoch 00021: val_accuracy did not improve from 0.58508
# Epoch 22/50
# 1061/1061 [==============================] - 257s 243ms/step - loss: 1.2939 - accuracy: 0.6124 - val_loss: 1.3870 - val_accuracy: 0.5876
#
# Epoch 00022: val_accuracy improved from 0.58508 to 0.58756, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 23/50
# 1061/1061 [==============================] - 258s 243ms/step - loss: 1.2790 - accuracy: 0.6153 - val_loss: 1.3817 - val_accuracy: 0.5881
#
# Epoch 00023: val_accuracy improved from 0.58756 to 0.58815, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 24/50
# 1061/1061 [==============================] - 259s 244ms/step - loss: 1.2668 - accuracy: 0.6189 - val_loss: 1.3820 - val_accuracy: 0.5906
#
# Epoch 00024: val_accuracy improved from 0.58815 to 0.59057, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 25/50
# 1061/1061 [==============================] - 260s 245ms/step - loss: 1.2539 - accuracy: 0.6204 - val_loss: 1.3725 - val_accuracy: 0.5919
#
# Epoch 00025: val_accuracy improved from 0.59057 to 0.59186, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 26/50
# 1061/1061 [==============================] - 259s 244ms/step - loss: 1.2372 - accuracy: 0.6270 - val_loss: 1.3688 - val_accuracy: 0.5936
#
# Epoch 00026: val_accuracy improved from 0.59186 to 0.59363, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 27/50
# 1061/1061 [==============================] - 258s 243ms/step - loss: 1.2286 - accuracy: 0.6314 - val_loss: 1.3626 - val_accuracy: 0.5923
#
# Epoch 00027: val_accuracy did not improve from 0.59363
# Epoch 28/50
# 1061/1061 [==============================] - 258s 243ms/step - loss: 1.2170 - accuracy: 0.6342 - val_loss: 1.3571 - val_accuracy: 0.5963
#
# Epoch 00028: val_accuracy improved from 0.59363 to 0.59634, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 29/50
# 1061/1061 [==============================] - 259s 244ms/step - loss: 1.2067 - accuracy: 0.6371 - val_loss: 1.3574 - val_accuracy: 0.5976
#
# Epoch 00029: val_accuracy improved from 0.59634 to 0.59758, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 30/50
# 1061/1061 [==============================] - 259s 244ms/step - loss: 1.1923 - accuracy: 0.6377 - val_loss: 1.3504 - val_accuracy: 0.5996
#
# Epoch 00030: val_accuracy improved from 0.59758 to 0.59959, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 31/50
# 1061/1061 [==============================] - 260s 245ms/step - loss: 1.1818 - accuracy: 0.6409 - val_loss: 1.3476 - val_accuracy: 0.5994
#
# Epoch 00031: val_accuracy did not improve from 0.59959
# Epoch 32/50
# 1061/1061 [==============================] - 258s 244ms/step - loss: 1.1703 - accuracy: 0.6456 - val_loss: 1.3445 - val_accuracy: 0.6002
#
# Epoch 00032: val_accuracy improved from 0.59959 to 0.60018, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 33/50
# 1061/1061 [==============================] - 259s 244ms/step - loss: 1.1595 - accuracy: 0.6502 - val_loss: 1.3433 - val_accuracy: 0.6019
#
# Epoch 00033: val_accuracy improved from 0.60018 to 0.60189, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 34/50
# 1061/1061 [==============================] - 266s 251ms/step - loss: 1.1461 - accuracy: 0.6540 - val_loss: 1.3397 - val_accuracy: 0.6026
#
# Epoch 00034: val_accuracy improved from 0.60189 to 0.60259, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 35/50
# 1061/1061 [==============================] - 264s 249ms/step - loss: 1.1355 - accuracy: 0.6578 - val_loss: 1.3364 - val_accuracy: 0.6034
#
# Epoch 00035: val_accuracy improved from 0.60259 to 0.60336, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 36/50
# 1061/1061 [==============================] - 264s 249ms/step - loss: 1.1281 - accuracy: 0.6571 - val_loss: 1.3311 - val_accuracy: 0.6060
#
# Epoch 00036: val_accuracy improved from 0.60336 to 0.60601, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 37/50
# 1061/1061 [==============================] - 264s 249ms/step - loss: 1.1159 - accuracy: 0.6618 - val_loss: 1.3289 - val_accuracy: 0.6055
#
# Epoch 00037: val_accuracy did not improve from 0.60601
# Epoch 38/50
# 1061/1061 [==============================] - 261s 245ms/step - loss: 1.1063 - accuracy: 0.6667 - val_loss: 1.3286 - val_accuracy: 0.6066
#
# Epoch 00038: val_accuracy improved from 0.60601 to 0.60660, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 39/50
# 1061/1061 [==============================] - 263s 248ms/step - loss: 1.0932 - accuracy: 0.6676 - val_loss: 1.3250 - val_accuracy: 0.6071
#
# Epoch 00039: val_accuracy improved from 0.60660 to 0.60708, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 40/50
# 1061/1061 [==============================] - 265s 249ms/step - loss: 1.0873 - accuracy: 0.6690 - val_loss: 1.3226 - val_accuracy: 0.6090
#
# Epoch 00040: val_accuracy improved from 0.60708 to 0.60902, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 41/50
# 1061/1061 [==============================] - 265s 250ms/step - loss: 1.0728 - accuracy: 0.6726 - val_loss: 1.3190 - val_accuracy: 0.6079
#
# Epoch 00041: val_accuracy did not improve from 0.60902
# Epoch 42/50
# 1061/1061 [==============================] - 262s 247ms/step - loss: 1.0655 - accuracy: 0.6758 - val_loss: 1.3216 - val_accuracy: 0.6068
#
# Epoch 00042: val_accuracy did not improve from 0.60902
# Epoch 43/50
# 1061/1061 [==============================] - 264s 248ms/step - loss: 1.0518 - accuracy: 0.6809 - val_loss: 1.3165 - val_accuracy: 0.6098
#
# Epoch 00043: val_accuracy improved from 0.60902 to 0.60985, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 44/50
# 1061/1061 [==============================] - 265s 250ms/step - loss: 1.0437 - accuracy: 0.6826 - val_loss: 1.3148 - val_accuracy: 0.6097
#
# Epoch 00044: val_accuracy did not improve from 0.60985
# Epoch 45/50
# 1061/1061 [==============================] - 258s 243ms/step - loss: 1.0344 - accuracy: 0.6855 - val_loss: 1.3132 - val_accuracy: 0.6114
#
# Epoch 00045: val_accuracy improved from 0.60985 to 0.61138, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 46/50
# 1061/1061 [==============================] - 257s 243ms/step - loss: 1.0244 - accuracy: 0.6897 - val_loss: 1.3123 - val_accuracy: 0.6112
#
# Epoch 00046: val_accuracy did not improve from 0.61138
# Epoch 47/50
# 1061/1061 [==============================] - 257s 242ms/step - loss: 1.0140 - accuracy: 0.6908 - val_loss: 1.3096 - val_accuracy: 0.6129
#
# Epoch 00047: val_accuracy improved from 0.61138 to 0.61285, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 48/50
# 1061/1061 [==============================] - 258s 243ms/step - loss: 1.0021 - accuracy: 0.6964 - val_loss: 1.3075 - val_accuracy: 0.6128
#
# Epoch 00048: val_accuracy did not improve from 0.61285
# Epoch 49/50
# 1061/1061 [==============================] - 258s 243ms/step - loss: 0.9962 - accuracy: 0.6966 - val_loss: 1.3077 - val_accuracy: 0.6139
#
# Epoch 00049: val_accuracy improved from 0.61285 to 0.61392, saving model to ./saves/InceptionV3/Iteration_4_3\checkpoint_InceptionV3_16122021_Shape-299x299_50Epochs.h5
# Epoch 50/50
# 1061/1061 [==============================] - 257s 242ms/step - loss: 0.9879 - accuracy: 0.7000 - val_loss: 1.3047 - val_accuracy: 0.6114
#
# Epoch 00050: val_accuracy did not improve from 0.61392
# Wall time: 3h 37min 53s

# %% [markdown]
# ***Save History results***

# %%
# Save History results
path = './saves/InceptionV3/Iteration_4_3/'
filename = 'history_InceptionV3_all_train_16122021_Shape-299x299_50Epochs'

# %%
#convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# history to json:  
hist_json_file = path + filename + '.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# history to csv: 
hist_csv_file = path + filename +'.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# history to pickle file
hist_df.to_pickle(path + filename +'.pkl')

# %% [markdown]
# ***Display Model loss , accuracy per epoch***

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model acc by epoch')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')
plt.show()

# %% [markdown]
#  ***Prediction - test_generator***

# %%
# %%time
#Prediction - Valid set
y_pred_proba = model.predict(valid_generator)

# l'argmax pour obtenir les classes prédites
y_pred_class = np.argmax(y_pred_proba,axis = 1).astype(int)

# To get classes from test generator
y_true = valid_generator.classes
# Out:
# Wall time: 57 s

# %% [markdown]
#  ***Evaluation - test_generator***

# %%
# %%time
#Get the accuracy score
valid_score = model.evaluate(valid_generator)
print("[INFO] Model metrics names:", model.metrics_names)
print("[INFO] Accuracy: {:.2f}%".format(valid_score[1] * 100)) 
print("[INFO] Loss: ",valid_score[0])
# Out:
# 266/266 [==============================] - 54s 201ms/step - loss: 1.3046 - accuracy: 0.6116
# [INFO] Model metrics names: ['loss', 'accuracy']
# [INFO] Accuracy: 61.16%
# [INFO] Loss:  1.3045521974563599
# Wall time: 54.2 s

# %%
f1_macro = f1_score(y_true, y_pred_class, average='macro')
print("[INFO] f1 score macro average: ",f1_macro)

f1_micro = f1_score(y_true, y_pred_class, average='micro')
print("[INFO] f1 score micro average: ",f1_micro)

f1_weighted = f1_score(y_true, y_pred_class, average='weighted')
print("[INFO] f1 score weighted average: ",f1_weighted)
# Out:
# [INFO] f1 score macro average:  0.5604850531063563
# [INFO] f1 score micro average:  0.611552729199788
# [INFO] f1 score weighted average:  0.6040752769648372

# %%
#Confusion matrix
matrix = confusion_matrix(y_true, y_pred_class)
fig , ax = plt.subplots(figsize = (24,20))
ax.matshow(matrix, cmap = plt.cm.Oranges , alpha = 0.3)
for i in range(matrix.shape[0]):
    for j in range (matrix.shape[1]):
        ax.text (x = j , y= i, s= matrix[i,j], va = 'center', ha = 'center', size = 'xx-large')
        
plt.xlabel('predicted', fontsize = 18)
plt.ylabel('Acutals', fontsize = 18)
plt.title('Confusion Matrix', fontsize = 18)
plt.show()
#print(matrix)

# %%
print(metrics.classification_report(y_true, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.53      0.52       621
#            1       0.53      0.43      0.48       483
#            2       0.64      0.60      0.62       154
#            3       0.41      0.38      0.39       508
#            4       0.50      0.46      0.48       656
#            5       0.58      0.58      0.58      1038
#            6       0.77      0.81      0.79       848
#            7       0.66      0.68      0.67       152
#            8       0.48      0.52      0.50      1021
#            9       0.55      0.30      0.39       168
#           10       0.64      0.74      0.69       956
#           11       0.61      0.64      0.63       939
#           12       0.48      0.30      0.37       375
#           13       0.55      0.45      0.49       290
#           14       0.68      0.68      0.68       949
#           15       0.43      0.34      0.38       508
#           16       0.79      0.86      0.82      2061
#           17       0.43      0.41      0.42       493
#           18       0.71      0.71      0.71       548
#           19       0.65      0.57      0.60       173
#           20       0.67      0.74      0.71       163
#           21       0.59      0.63      0.61       546
#           22       0.83      0.91      0.87       791
#           23       0.55      0.30      0.39       154
#           24       0.42      0.39      0.40       963
#           25       0.30      0.23      0.26       405
#           26       0.62      0.75      0.68      1020
#
#     accuracy                           0.61     16983
#    macro avg       0.58      0.55      0.56     16983
# weighted avg       0.60      0.61      0.60     16983

# %% [markdown]
#  ***Predict input image using trained model***

# %%
# Predict With Pre Trained

# Load an image
im_id = 220
#img_path ='./data/images/all/image_train_resized/'+ df_train_im['imagePath'][im_id]
img_path ='./data/images/all/image_train/'+ df_train_im['imagePath'][im_id]

img = image.load_img(img_path,target_size=(224, 224))
plt.figure(figsize=(6,4))
plt.imshow(img)
plt.title("class: " + str(df_train_im['prdtypecode'][im_id]))
plt.xticks([])
plt.yticks([])
#plt.axis('off')
plt.show();

# %%
im = cv2.resize(cv2.imread(img_path), (299, 299))
im = np.expand_dims(im, axis=0)

# %%
out = model.predict(im)
print("------------------Predicted Class and Label ------------------------------")
print("target class(used by model) :", np.argmax(out))
print("\n"  ,df_class[df_class['target_prdtypecode'] == np.argmax(out)][['prdtypecode', 'Label']].to_string(index=False)) 

prd_code = df_train_im['prdtypecode'][im_id]

print("\n\n------------------Real Class and Label ------------------------------")
print("target class(used by model): " ,  df_class[df_class['target_prdtypecode'] == int(prd_code)]['target_prdtypecode'].to_string(index=False))
print("\n"  ,df_class[df_class['target_prdtypecode'] == int(prd_code)][['prdtypecode', 'Label']].to_string(index=False))
# Out:
# ------------------Predicted Class and Label ------------------------------
# target class(used by model) : 3
#
#   prdtypecode              Label
#           60 games and consoles
#
#
# ------------------Real Class and Label ------------------------------
# target class(used by model):  13
#
#   prdtypecode                          Label
#         1560 interior furniture and bedding

# %% [markdown]
#  ***Save InceptionV3 Model***

# %%
#Enregistrement du modèle
model.save("./saves/InceptionV3/Iteration_4_3/Model_InceptionV3_All_train_data_16122021_Shape-299x299_50Epochs.hdf5")
#The SavedModel and HDF5 file contains:
#the model's configuration (topology)
#the model's weights
#the model's optimizer's state (if any)

# %% [markdown]
#  ***Load InceptionV3 Model***

# %%
#Rechargement du modèle :
model = load_model('./saves/InceptionV3/Iteration_4_3/Model_InceptionV3_All_train_data_16122021_Shape-299x299_50Epochs.hdf5')
