# %% [markdown]
# #  InceptionResNetV2 : Images - Iteration #4_3(Without Data Augementation)

# %% [markdown]
# img_rows = 299 <br>
# img_cols = 299 <br>
# batch_size = 64 <br>
# epochs = 50 <br>
# Train set size = 67933 <br>
# Valid set size = 16983 <br>
# <font color = 'red'> Without Fine tuning , just LR 0.001 to 1e-5 </font>

# %% [markdown]
# **<u>Results</u>**

# %% [markdown]
# Accuracy : 0.62 <br>
# F1 score weighted : 0.61

# %% [markdown]
# **Import packages**

# %%
import os
import glob
import pandas as pd
import numpy as np
import cv2
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from tqdm.notebook import tqdm_notebook
import re
tqdm_notebook.pandas()
import tensorflow as tf
#from tensorflow import keras
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.efficientnet import EfficientNetB7
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn import metrics
import itertools
import pickle
from joblib import dump, load

# %% [markdown]
# # Iteration #4_3 - InceptionResNetV2

# %% [markdown]
# ***Read DataFrame from saved pickele file - image Train set***

# %%
#Load df of images already resized on 256 x 256 
#df_train_im = pd.read_pickle("./saves/df_save/df_train_combined_19102021.pkl")

#Load df of images with org size 500 x 500
df_train_im = pd.read_pickle("./saves/df_save/df_train_combined_ORG_im_size_02122021.pkl")

# %%
df_train_im.head()
# Out:
#                                          designation  \
# 0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#    prdtypecode                                imagePath
# 0           10  image_1263597046_product_3804725264.jpg
# 1         2280   image_1008141237_product_436067568.jpg
# 2           50    image_938777978_product_201115110.jpg
# 3         1280     image_457047496_product_50418756.jpg
# 4         2705   image_1077757786_product_278535884.jpg

# %%
display(df_train_im.shape)
# Out:
# (84916, 6)

# %% [markdown]
# ***Create Dataframe containing  product classes and their associated labels***

# %%
#Dictionary of prdtypecode and their corresponding categories
dict_prdtypecode = {"prdtypecode" : [50, 2705, 2522, 2582, 1560, 1281, 1920, 1280, 1140, 1300, 2060, 2583,
                                     60, 1320, 2280, 1302, 2220, 40, 2905, 2585, 1940, 1160, 1301, 10, 1180,
                                     2403, 2462],                 
            
                    "Label" : ["video games accessories", "books", "stationery", "kitchen and garden", 
                               "interior furniture and bedding", "board games", "interior accessories",
                               "toys for children","goodies", "remote controlled models", "decoration interior",
                               "piscine spa","games and consoles", "early childhood", "magazines", "kids toys",
                               "supplies for domestic animals", "imported video games", "online distribution of video games",
                               "gardening and DIY","Food","playing cards", "accessories children", "adult books",
                               "figurines_wargames", "children books",
                                "games"]
                   }
df_class = pd.DataFrame(data=dict_prdtypecode)
df_class
# Out:
#     prdtypecode                               Label
# 0            50             video games accessories
# 1          2705                               books
# 2          2522                          stationery
# 3          2582                  kitchen and garden
# 4          1560      interior furniture and bedding
# 5          1281                         board games
# 6          1920                interior accessories
# 7          1280                   toys for children
# 8          1140                             goodies
# 9          1300            remote controlled models
# 10         2060                 decoration interior
# 11         2583                         piscine spa
# 12           60                  games and consoles
# 13         1320                     early childhood
# 14         2280                           magazines
# 15         1302                           kids toys
# 16         2220       supplies for domestic animals
# 17           40                imported video games
# 18         2905  online distribution of video games
# 19         2585                   gardening and DIY
# 20         1940                                Food
# 21         1160                       playing cards
# 22         1301                accessories children
# 23           10                         adult books
# 24         1180                  figurines_wargames
# 25         2403                      children books
# 26         2462                               games

# %%
# Crate DF containing prdtypecode , categories and corresponding class used by model
df_class = df_class.sort_values(by = 'prdtypecode', ascending = True)
df_class['target_prdtypecode'] = [i for i in range(27)]
df_class
# Out:
#     prdtypecode                               Label  target_prdtypecode
# 23           10                         adult books                   0
# 17           40                imported video games                   1
# 0            50             video games accessories                   2
# 12           60                  games and consoles                   3
# 8          1140                             goodies                   4
# 21         1160                       playing cards                   5
# 24         1180                  figurines_wargames                   6
# 7          1280                   toys for children                   7
# 5          1281                         board games                   8
# 9          1300            remote controlled models                   9
# 22         1301                accessories children                  10
# 15         1302                           kids toys                  11
# 13         1320                     early childhood                  12
# 4          1560      interior furniture and bedding                  13
# 6          1920                interior accessories                  14
# 20         1940                                Food                  15
# 10         2060                 decoration interior                  16
# 16         2220       supplies for domestic animals                  17
# 14         2280                           magazines                  18
# 25         2403                      children books                  19
# 26         2462                               games                  20
# 2          2522                          stationery                  21
# 3          2582                  kitchen and garden                  22
# 11         2583                         piscine spa                  23
# 19         2585                   gardening and DIY                  24
# 1          2705                               books                  25
# 18         2905  online distribution of video games                  26

# %% [markdown]
# ***Change the 27 product codes to 0 to 26***

# %%
df_train_im.replace({'prdtypecode':{10:0,
                                    40:1,
                                    50:2,
                                    60:3,
                                    1140:4,
                                    1160:5,
                                    1180:6,
                                    1280:7,
                                    1281:8,
                                    1300:9                                    
                                    }}, inplace = True)

df_train_im.replace({'prdtypecode':{1301:10,
                                    1302:11,
                                    1320:12,
                                    1560:13,
                                    1920:14,
                                    1940:15,
                                    2060:16,
                                    2220:17,
                                    2280:18,
                                    2403:19,
                                    2462:20,
                                    2522:21,
                                    2582:22,
                                    2583:23,
                                    2585:24,
                                    2705:25,
                                    2905:26
                                    }}, inplace = True)

# %%
display(df_train_im["prdtypecode"].unique())
# Out:
# array([ 0, 18,  2,  7, 25, 21, 22, 13,  8, 14, 19,  4, 23,  6,  9, 20,  5,
#        16,  1,  3, 12, 11, 17, 26, 24, 15, 10], dtype=int64)

# %% [markdown]
#  ***Convert product code to string type***

# %%
df_train_im["prdtypecode"] = df_train_im["prdtypecode"].astype(str)

# %%
unique, counts = np.unique(df_train_im["prdtypecode"], return_counts=True)
dict(zip(unique, counts))
# Out:
# {'0': 3116,
#  '1': 2508,
#  '10': 807,
#  '11': 2491,
#  '12': 3241,
#  '13': 5073,
#  '14': 4303,
#  '15': 803,
#  '16': 4993,
#  '17': 824,
#  '18': 4760,
#  '19': 4774,
#  '2': 1681,
#  '20': 1421,
#  '21': 4989,
#  '22': 2589,
#  '23': 10209,
#  '24': 2496,
#  '25': 2761,
#  '26': 872,
#  '3': 832,
#  '4': 2671,
#  '5': 3953,
#  '6': 764,
#  '7': 4870,
#  '8': 2070,
#  '9': 5045}

# %% [markdown]
#  ***Split Train Set***

# %%
# Split Train set 
#X_train_im, X_test_im = train_test_split(df_train_im, train_size=0.8, random_state=1234)

# %%
#display(X_train_im.shape)
#display(X_test_im.shape)

# %% [markdown]
# ***Data Generator***

# %%
# %%time
#Générateur de données
img_gen = ImageDataGenerator(rescale = 1/255, 
                             validation_split = 0.2)
# Out:
# Wall time: 0 ns

# %%
img_rows = 299
img_cols = 299
batch_size = 64
epochs = 50

# Directory of images already resized on 256 x 256 
#images_dir_train = './data/images/all/image_train_resized/'
#images_dir_train = 'E:/WorkSpace_DataScience_E/Rakuten_Projet_Local/My_WS/data/images/all/image_train_resized/'

# Directory of images org resize 500 x 500
images_dir_train = './data/images/all/image_train/'
#images_dir_train = 'E:/WorkSpace_DataScience_E/Rakuten_Projet_Local/My_WS/data/images/all/image_train/'

# %%
# %%time

#Itérateur 
train_generator = img_gen.flow_from_dataframe(dataframe = df_train_im,
                                              directory = images_dir_train,
                                              as_ext = True,
                                              x_col = 'imagePath',
                                              y_col = 'prdtypecode',  #target data                                            
                                              class_mode = 'sparse',                                             
                                              target_size = (img_rows , img_cols), # default 256 x 256                                             
                                              batch_size = batch_size,                                             
                                              shuffle = True, # défault
                                              subset = 'training'
                                             )
# Out:
# Found 67933 validated image filenames belonging to 27 classes.
# Wall time: 8.89 s

# %%
# %%time
# validation_split the validation batches ca be retrieved by specifying the subset as validation.
valid_generator = img_gen.flow_from_dataframe(dataframe = df_train_im, 
                                              directory = images_dir_train,
                                              as_ext = True,
                                              x_col = 'imagePath',
                                              y_col = 'prdtypecode',  #target data                                            
                                              class_mode = 'sparse',                                        
                                              target_size = (img_rows , img_cols), # default 256 x 256                                         
                                              batch_size = batch_size, 
                                              shuffle = False,
                                              subset  = 'validation'
                                             )
# Out:
# Found 16983 validated image filenames belonging to 27 classes.
# Wall time: 5.71 s

# %% [markdown]
#  ***InceptionResNetV2 Implementation***

# %%
# %%time
# Chargement du modèle inceptionResNetV2
inceptionResNetV2 = InceptionResNetV2(weights='imagenet', include_top = False, input_shape=(img_rows,img_rows,3))

# Bloquage du blackbone
for layer in inceptionResNetV2.layers:
    layer.trainable = False
    
model = Sequential()
model.add(inceptionResNetV2)
# Ajout des couche de classification
model.add(GlobalAveragePooling2D()) 
model.add(Dense(units = 1024,activation='relu'))

model.add(Dropout(rate = 0.2))
model.add(Dense(units = 512, activation='relu'))

model.add(Dropout(rate = 0.2))
model.add(Dense(units = 27, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v2 (Functio (None, 8, 8, 1536)        54336736
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              1573888
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 27)                13851
# =================================================================
# Total params: 56,449,275
# Trainable params: 2,112,539
# Non-trainable params: 54,336,736
# _________________________________________________________________
# Wall time: 6.61 s

# %% [markdown]
#  ***Compilation***

# %%
# %%time
# Compilation
model.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer= Adam(learning_rate= 1e-5) ,   #default lr = 0.001 # algorithme de descente de gradient
              metrics=['accuracy'])                    # métrique d'évaluation
# Out:
# Wall time: 15 ms

# %% [markdown]
# ***Callbacks***

# %%
# %%time
path = './saves/InceptionResNetV2/Iteration_4_3/'
file_name = 'checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5'

#Sauvegarder les meilleurs poids du modèle au cours de l'entraînement :
checkpoint = ModelCheckpoint(filepath = path + file_name , 
                             monitor ='val_accuracy',
                             verbose = 1,
                             save_best_only = True, # (pour que le meilleur modèle ne soit pas écrasé)
                             save_weights_only = False,
                             mode ='max', #(permet de préciser si la métrique doit croître ou décroitre : ici on choisit 'min'
                                           #car la métrique est une perte à minimiser)
                             save_freq='epoch')
#Arrêter l'entraînement si le modèle n'évolue plus (très pratique pour ne pas gérer le
#nombre d'epoch) :
early = EarlyStopping(monitor='val_loss',
                      min_delta = 0,
                      patience = 10, #(nombre d'epochs à attendre avant d'arrêter l'entraînement
                      restore_best_weights = True,
                      verbose = 1,
                      mode = 'min')

#Réduire automatiquement le learning rate :
lr_plateau = ReduceLROnPlateau(monitor = 'val_loss',
                               patience = 10,
                               verbose = 1,
                                mode='min'
                               )
# Out:
# Wall time: 0 ns

# %% [markdown]
#  ***Fit - train_generator***

# %%
step_size_Train = train_generator.n//train_generator.batch_size
step_size_Valid = valid_generator.n//valid_generator.batch_size
print('step_size_Train : ' , step_size_Train)
print('step_size_Valid  : ' , step_size_Valid)
# Out:
# step_size_Train :  1061
# step_size_Valid  :  265

# %%
# %%time
# Fit Train generator
history = model.fit(train_generator,                    
                    epochs = epochs,                   
                    steps_per_epoch = step_size_Train,
                    validation_data = valid_generator,
                    validation_steps = step_size_Valid,
                    callbacks=[checkpoint, early, lr_plateau]                    
                    )
# Out:
# Epoch 1/50
# 1061/1061 [==============================] - 416s 377ms/step - loss: 2.4776 - accuracy: 0.3262 - val_loss: 1.9723 - val_accuracy: 0.4515
#
# Epoch 00001: val_accuracy improved from -inf to 0.45147, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 2/50
# 1061/1061 [==============================] - 400s 377ms/step - loss: 1.9372 - accuracy: 0.4505 - val_loss: 1.7533 - val_accuracy: 0.4975
#
# Epoch 00002: val_accuracy improved from 0.45147 to 0.49752, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 3/50
# 1061/1061 [==============================] - 403s 379ms/step - loss: 1.7900 - accuracy: 0.4829 - val_loss: 1.6649 - val_accuracy: 0.5160
#
# Epoch 00003: val_accuracy improved from 0.49752 to 0.51604, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 4/50
# 1061/1061 [==============================] - 404s 381ms/step - loss: 1.7111 - accuracy: 0.5013 - val_loss: 1.6162 - val_accuracy: 0.5284
#
# Epoch 00004: val_accuracy improved from 0.51604 to 0.52842, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 5/50
# 1061/1061 [==============================] - 405s 381ms/step - loss: 1.6545 - accuracy: 0.5162 - val_loss: 1.5788 - val_accuracy: 0.5389
#
# Epoch 00005: val_accuracy improved from 0.52842 to 0.53886, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 6/50
# 1061/1061 [==============================] - 404s 380ms/step - loss: 1.6138 - accuracy: 0.5253 - val_loss: 1.5514 - val_accuracy: 0.5455
#
# Epoch 00006: val_accuracy improved from 0.53886 to 0.54546, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 7/50
# 1061/1061 [==============================] - 403s 380ms/step - loss: 1.5782 - accuracy: 0.5340 - val_loss: 1.5290 - val_accuracy: 0.5511
#
# Epoch 00007: val_accuracy improved from 0.54546 to 0.55106, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 8/50
# 1061/1061 [==============================] - 404s 381ms/step - loss: 1.5509 - accuracy: 0.5423 - val_loss: 1.5066 - val_accuracy: 0.5577
#
# Epoch 00008: val_accuracy improved from 0.55106 to 0.55767, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 9/50
# 1061/1061 [==============================] - 404s 381ms/step - loss: 1.5273 - accuracy: 0.5480 - val_loss: 1.4921 - val_accuracy: 0.5596
#
# Epoch 00009: val_accuracy improved from 0.55767 to 0.55961, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 10/50
# 1061/1061 [==============================] - 405s 381ms/step - loss: 1.5032 - accuracy: 0.5531 - val_loss: 1.4768 - val_accuracy: 0.5674
#
# Epoch 00010: val_accuracy improved from 0.55961 to 0.56739, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 11/50
# 1061/1061 [==============================] - 405s 382ms/step - loss: 1.4817 - accuracy: 0.5617 - val_loss: 1.4628 - val_accuracy: 0.5699
#
# Epoch 00011: val_accuracy improved from 0.56739 to 0.56987, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 12/50
# 1061/1061 [==============================] - 406s 382ms/step - loss: 1.4651 - accuracy: 0.5648 - val_loss: 1.4495 - val_accuracy: 0.5723
#
# Epoch 00012: val_accuracy improved from 0.56987 to 0.57229, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 13/50
# 1061/1061 [==============================] - 405s 382ms/step - loss: 1.4494 - accuracy: 0.5684 - val_loss: 1.4391 - val_accuracy: 0.5767
#
# Epoch 00013: val_accuracy improved from 0.57229 to 0.57671, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 14/50
# 1061/1061 [==============================] - 406s 382ms/step - loss: 1.4311 - accuracy: 0.5740 - val_loss: 1.4285 - val_accuracy: 0.5783
#
# Epoch 00014: val_accuracy improved from 0.57671 to 0.57830, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 15/50
# 1061/1061 [==============================] - 406s 382ms/step - loss: 1.4153 - accuracy: 0.5778 - val_loss: 1.4192 - val_accuracy: 0.5825
#
# Epoch 00015: val_accuracy improved from 0.57830 to 0.58255, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 16/50
# 1061/1061 [==============================] - 407s 383ms/step - loss: 1.4009 - accuracy: 0.5825 - val_loss: 1.4106 - val_accuracy: 0.5817
#
# Epoch 00016: val_accuracy did not improve from 0.58255
# Epoch 17/50
# 1061/1061 [==============================] - 407s 384ms/step - loss: 1.3846 - accuracy: 0.5853 - val_loss: 1.4016 - val_accuracy: 0.5863
#
# Epoch 00017: val_accuracy improved from 0.58255 to 0.58626, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 18/50
# 1061/1061 [==============================] - 409s 385ms/step - loss: 1.3739 - accuracy: 0.5904 - val_loss: 1.3958 - val_accuracy: 0.5860
#
# Epoch 00018: val_accuracy did not improve from 0.58626
# Epoch 19/50
# 1061/1061 [==============================] - 419s 395ms/step - loss: 1.3599 - accuracy: 0.5938 - val_loss: 1.3862 - val_accuracy: 0.5896
#
# Epoch 00019: val_accuracy improved from 0.58626 to 0.58956, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 20/50
# 1061/1061 [==============================] - 411s 387ms/step - loss: 1.3507 - accuracy: 0.5966 - val_loss: 1.3813 - val_accuracy: 0.5904
#
# Epoch 00020: val_accuracy improved from 0.58956 to 0.59039, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 21/50
# 1061/1061 [==============================] - 410s 387ms/step - loss: 1.3387 - accuracy: 0.5992 - val_loss: 1.3744 - val_accuracy: 0.5932
#
# Epoch 00021: val_accuracy improved from 0.59039 to 0.59316, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 22/50
# 1061/1061 [==============================] - 496s 467ms/step - loss: 1.3276 - accuracy: 0.6031 - val_loss: 1.3673 - val_accuracy: 0.5954
#
# Epoch 00022: val_accuracy improved from 0.59316 to 0.59540, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 23/50
# 1061/1061 [==============================] - 509s 480ms/step - loss: 1.3180 - accuracy: 0.6050 - val_loss: 1.3614 - val_accuracy: 0.5965
#
# Epoch 00023: val_accuracy improved from 0.59540 to 0.59646, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 24/50
# 1061/1061 [==============================] - 509s 479ms/step - loss: 1.3053 - accuracy: 0.6075 - val_loss: 1.3569 - val_accuracy: 0.5974
#
# Epoch 00024: val_accuracy improved from 0.59646 to 0.59741, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 25/50
# 1061/1061 [==============================] - 509s 479ms/step - loss: 1.2968 - accuracy: 0.6092 - val_loss: 1.3522 - val_accuracy: 0.5978
#
# Epoch 00025: val_accuracy improved from 0.59741 to 0.59782, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 26/50
# 1061/1061 [==============================] - 509s 480ms/step - loss: 1.2838 - accuracy: 0.6132 - val_loss: 1.3448 - val_accuracy: 0.6012
#
# Epoch 00026: val_accuracy improved from 0.59782 to 0.60118, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 27/50
# 1061/1061 [==============================] - 510s 480ms/step - loss: 1.2751 - accuracy: 0.6151 - val_loss: 1.3392 - val_accuracy: 0.6006
#
# Epoch 00027: val_accuracy did not improve from 0.60118
# Epoch 28/50
# 1061/1061 [==============================] - 424s 400ms/step - loss: 1.2684 - accuracy: 0.6195 - val_loss: 1.3352 - val_accuracy: 0.6037
#
# Epoch 00028: val_accuracy improved from 0.60118 to 0.60371, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 29/50
# 1061/1061 [==============================] - 416s 392ms/step - loss: 1.2576 - accuracy: 0.6234 - val_loss: 1.3324 - val_accuracy: 0.6022
#
# Epoch 00029: val_accuracy did not improve from 0.60371
# Epoch 30/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.2502 - accuracy: 0.6223 - val_loss: 1.3276 - val_accuracy: 0.6047
#
# Epoch 00030: val_accuracy improved from 0.60371 to 0.60472, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 31/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.2400 - accuracy: 0.6252 - val_loss: 1.3225 - val_accuracy: 0.6047
#
# Epoch 00031: val_accuracy did not improve from 0.60472
# Epoch 32/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.2305 - accuracy: 0.6299 - val_loss: 1.3172 - val_accuracy: 0.6080
#
# Epoch 00032: val_accuracy improved from 0.60472 to 0.60802, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 33/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.2231 - accuracy: 0.6292 - val_loss: 1.3145 - val_accuracy: 0.6068
#
# Epoch 00033: val_accuracy did not improve from 0.60802
# Epoch 34/50
# 1061/1061 [==============================] - 415s 391ms/step - loss: 1.2140 - accuracy: 0.6341 - val_loss: 1.3132 - val_accuracy: 0.6083
#
# Epoch 00034: val_accuracy improved from 0.60802 to 0.60831, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 35/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.2065 - accuracy: 0.6369 - val_loss: 1.3047 - val_accuracy: 0.6100
#
# Epoch 00035: val_accuracy improved from 0.60831 to 0.61002, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 36/50
# 1061/1061 [==============================] - 415s 391ms/step - loss: 1.1991 - accuracy: 0.6376 - val_loss: 1.3049 - val_accuracy: 0.6111
#
# Epoch 00036: val_accuracy improved from 0.61002 to 0.61108, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 37/50
# 1061/1061 [==============================] - 415s 391ms/step - loss: 1.1920 - accuracy: 0.6395 - val_loss: 1.3039 - val_accuracy: 0.6109
#
# Epoch 00037: val_accuracy did not improve from 0.61108
# Epoch 38/50
# 1061/1061 [==============================] - 415s 391ms/step - loss: 1.1822 - accuracy: 0.6415 - val_loss: 1.2979 - val_accuracy: 0.6120
#
# Epoch 00038: val_accuracy improved from 0.61108 to 0.61203, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 39/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.1755 - accuracy: 0.6443 - val_loss: 1.2929 - val_accuracy: 0.6152
#
# Epoch 00039: val_accuracy improved from 0.61203 to 0.61515, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 40/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.1664 - accuracy: 0.6477 - val_loss: 1.2909 - val_accuracy: 0.6136
#
# Epoch 00040: val_accuracy did not improve from 0.61515
# Epoch 41/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.1583 - accuracy: 0.6479 - val_loss: 1.2894 - val_accuracy: 0.6152
#
# Epoch 00041: val_accuracy did not improve from 0.61515
# Epoch 42/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.1523 - accuracy: 0.6505 - val_loss: 1.2853 - val_accuracy: 0.6162
#
# Epoch 00042: val_accuracy improved from 0.61515 to 0.61621, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 43/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.1437 - accuracy: 0.6516 - val_loss: 1.2837 - val_accuracy: 0.6169
#
# Epoch 00043: val_accuracy improved from 0.61621 to 0.61686, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 44/50
# 1061/1061 [==============================] - 413s 389ms/step - loss: 1.1360 - accuracy: 0.6536 - val_loss: 1.2811 - val_accuracy: 0.6168
#
# Epoch 00044: val_accuracy did not improve from 0.61686
# Epoch 45/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.1273 - accuracy: 0.6591 - val_loss: 1.2782 - val_accuracy: 0.6182
#
# Epoch 00045: val_accuracy improved from 0.61686 to 0.61816, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 46/50
# 1061/1061 [==============================] - 414s 390ms/step - loss: 1.1227 - accuracy: 0.6574 - val_loss: 1.2759 - val_accuracy: 0.6193
#
# Epoch 00046: val_accuracy improved from 0.61816 to 0.61934, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 47/50
# 1061/1061 [==============================] - 415s 391ms/step - loss: 1.1146 - accuracy: 0.6600 - val_loss: 1.2719 - val_accuracy: 0.6191
#
# Epoch 00047: val_accuracy did not improve from 0.61934
# Epoch 48/50
# 1061/1061 [==============================] - 415s 391ms/step - loss: 1.1093 - accuracy: 0.6636 - val_loss: 1.2710 - val_accuracy: 0.6203
#
# Epoch 00048: val_accuracy improved from 0.61934 to 0.62034, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 49/50
# 1061/1061 [==============================] - 415s 391ms/step - loss: 1.1045 - accuracy: 0.6636 - val_loss: 1.2663 - val_accuracy: 0.6232
#
# Epoch 00049: val_accuracy improved from 0.62034 to 0.62323, saving model to ./saves/InceptionResNetV2/Iteration_4_3\checkpoint_InceptionResNetV2_22122021_299x299_50Epochs.h5
# Epoch 50/50
# 1061/1061 [==============================] - 416s 392ms/step - loss: 1.0938 - accuracy: 0.6660 - val_loss: 1.2658 - val_accuracy: 0.6219
#
# Epoch 00050: val_accuracy did not improve from 0.62323
# Wall time: 5h 52min 46s

# %% [markdown]
# ***Save History results***

# %%
# Save History results
path = './saves/InceptionResNetV2/Iteration_4_3/'
filename = 'history_InceptionResNetV2_all_train_22122021_299x299_50Epochs'

# %%
#convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# history to json:  
hist_json_file = path + filename + '.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# history to csv: 
hist_csv_file = path + filename +'.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# history to pickle file
hist_df.to_pickle(path + filename +'.pkl')

# %% [markdown]
# ***Display Model loss , accuracy per epoch***

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model acc by epoch')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')
plt.show()

# %% [markdown]
#  ***Prediction - test_generator***

# %%
# %%time
#Prediction - Valid set
y_pred_proba = model.predict(valid_generator)

# l'argmax pour obtenir les classes prédites
y_pred_class = np.argmax(y_pred_proba,axis = 1).astype(int)

# To get classes from test generator
y_true = valid_generator.classes
# Out:
# Wall time: 1min 18s

# %% [markdown]
#  ***Evaluation - test_generator***

# %%
# %%time
#Get the accuracy score
valid_score = model.evaluate(valid_generator)
print("[INFO] Model metrics names:", model.metrics_names)
print("[INFO] Accuracy: {:.2f}%".format(valid_score[1] * 100)) 
print("[INFO] Loss: ",valid_score[0])
# Out:
# 266/266 [==============================] - 80s 299ms/step - loss: 1.2657 - accuracy: 0.6220
# [INFO] Model metrics names: ['loss', 'accuracy']
# [INFO] Accuracy: 62.20%
# [INFO] Loss:  1.2656664848327637
# Wall time: 1min 20s

# %%
f1_macro = f1_score(y_true, y_pred_class, average='macro')
print("[INFO] f1 score macro average: ",f1_macro)

f1_micro = f1_score(y_true, y_pred_class, average='micro')
print("[INFO] f1 score micro average: ",f1_micro)

f1_weighted = f1_score(y_true, y_pred_class, average='weighted')
print("[INFO] f1 score weighted average: ",f1_weighted)
# Out:
# [INFO] f1 score macro average:  0.5675059426972996
# [INFO] f1 score micro average:  0.6219749160925632
# [INFO] f1 score weighted average:  0.6118897484092088

# %%
#Confusion matrix
matrix = confusion_matrix(y_true, y_pred_class)
fig , ax = plt.subplots(figsize = (24,20))
ax.matshow(matrix, cmap = plt.cm.Oranges , alpha = 0.3)
for i in range(matrix.shape[0]):
    for j in range (matrix.shape[1]):
        ax.text (x = j , y= i, s= matrix[i,j], va = 'center', ha = 'center', size = 'xx-large')
        
plt.xlabel('predicted', fontsize = 18)
plt.ylabel('Acutals', fontsize = 18)
plt.title('Confusion Matrix', fontsize = 18)
plt.show()
#print(matrix)

# %%
print(metrics.classification_report(y_true, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.50      0.49       621
#            1       0.52      0.43      0.47       483
#            2       0.66      0.64      0.65       154
#            3       0.50      0.39      0.44       508
#            4       0.53      0.41      0.47       656
#            5       0.59      0.62      0.60      1038
#            6       0.79      0.83      0.81       848
#            7       0.65      0.69      0.67       152
#            8       0.51      0.55      0.53      1021
#            9       0.58      0.36      0.44       168
#           10       0.63      0.70      0.66       956
#           11       0.62      0.66      0.64       939
#           12       0.57      0.32      0.41       375
#           13       0.61      0.48      0.54       290
#           14       0.65      0.71      0.68       949
#           15       0.59      0.33      0.42       508
#           16       0.77      0.87      0.81      2061
#           17       0.45      0.41      0.43       493
#           18       0.67      0.75      0.71       548
#           19       0.55      0.62      0.58       173
#           20       0.68      0.71      0.69       163
#           21       0.59      0.63      0.61       546
#           22       0.88      0.88      0.88       791
#           23       0.42      0.21      0.28       154
#           24       0.44      0.45      0.44       963
#           25       0.41      0.20      0.27       405
#           26       0.62      0.79      0.69      1020
#
#     accuracy                           0.62     16983
#    macro avg       0.59      0.56      0.57     16983
# weighted avg       0.61      0.62      0.61     16983

# %% [markdown]
#  ***Predict input image using trained model***

# %%
# Predict With Pre Trained

# Load an image
im_id = 129
img_path ='./data/images/all/image_train/'+ df_train_im['imagePath'][im_id]

img = image.load_img(img_path,target_size=(299, 299))
plt.figure(figsize=(6,4))
plt.imshow(img)
plt.title("class: " + str(df_train_im['prdtypecode'][im_id]))
plt.xticks([])
plt.yticks([])
#plt.axis('off')
plt.show();

# %%
im = cv2.resize(cv2.imread(img_path), (299, 299))
im = np.expand_dims(im, axis=0)

# %%
out = model.predict(im)
print("------------------Predicted Class and Label ------------------------------")
print("target class(used by model) :", np.argmax(out))
print("\n"  ,df_class[df_class['target_prdtypecode'] == np.argmax(out)][['prdtypecode', 'Label']].to_string(index=False)) 

prd_code = df_train_im['prdtypecode'][im_id]

print("\n\n------------------Real Class and Label ------------------------------")
print("target class(used by model): " ,  df_class[df_class['target_prdtypecode'] == int(prd_code)]['target_prdtypecode'].to_string(index=False))
print("\n"  ,df_class[df_class['target_prdtypecode'] == int(prd_code)][['prdtypecode', 'Label']].to_string(index=False))
# Out:
# ------------------Predicted Class and Label ------------------------------
# target class(used by model) : 10
#
#   prdtypecode                Label
#         1301 accessories children
#
#
# ------------------Real Class and Label ------------------------------
# target class(used by model):  18
#
#   prdtypecode     Label
#         2280 magazines

# %% [markdown]
#  ***Save InceptionResNetV2 Model***

# %%
#Enregistrement du modèle
model.save("./saves/InceptionResNetV2/Iteration_4_3/Model_InceptionResNetV2_All_train_data_22122021_299x299_50Epochs.hdf5")
#The SavedModel and HDF5 file contains:
#the model's configuration (topology)
#the model's weights
#the model's optimizer's state (if any)

# %% [markdown]
#  ***Load InceptionResNetV2 Model***

# %%
#Rechargement du modèle :
model = load_model('./saves/InceptionResNetV2/Iteration_4_3/Model_InceptionResNetV2_All_train_data_22122021_299x299_50Epochs.hdf5')
