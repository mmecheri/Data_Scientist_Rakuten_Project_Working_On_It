# %% [markdown]
# # MobileNetV2 : Images - Iteration #4_3(Without Data Augementation)

# %% [markdown]
# img_rows = 224 <br>
# img_cols = 224 <br>
# batch_size = 64 <br>
# epochs = 50 <br>
# Train set size = 67933 <br>
# Valid set size = 16983 <br>
# <font color = 'red'> Without Fine tuning , just LR 0.001 to 1e-5 </font>

# %% [markdown]
# **<u>Results</u>**

# %% [markdown]
# Accuracy : 0.61 <br>
# F1 score weighted : 0.60

# %% [markdown]
# **Import packages**

# %%
import os
import glob
import pandas as pd
import numpy as np
import cv2
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from tqdm.notebook import tqdm_notebook
import re
tqdm_notebook.pandas()
import tensorflow as tf
#from tensorflow import keras
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.efficientnet import EfficientNetB7
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import f1_score , recall_score, accuracy_score, precision_score, confusion_matrix
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn import metrics
import itertools
import pickle
from joblib import dump, load

# %% [markdown]
# # Iteration #4_3 - MobileNetV2

# %% [markdown]
# ***Read DataFrame from saved pickele file - image Train set***

# %%
#Load df of images already resized on 256 x 256 
df_train_im = pd.read_pickle("./saves/df_save/df_train_combined_19102021.pkl")

#Load df of images with org size 500 x 500
#df_train_im = pd.read_pickle("./saves/df_save/df_train_combined_ORG_im_size_23112021.pkl")

# %%
df_train_im.head()
# Out:
#                                          designation  \
# 0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#    prdtypecode                                        imagePath
# 0           10  resized_image_1263597046_product_3804725264.jpg
# 1         2280   resized_image_1008141237_product_436067568.jpg
# 2           50    resized_image_938777978_product_201115110.jpg
# 3         1280     resized_image_457047496_product_50418756.jpg
# 4         2705   resized_image_1077757786_product_278535884.jpg

# %%
display(df_train_im.shape)
# Out:
# (84916, 6)

# %% [markdown]
# ***Create Dataframe containing  product classes and their associated labels***

# %%
#Dictionary of prdtypecode and their corresponding categories
dict_prdtypecode = {"prdtypecode" : [50, 2705, 2522, 2582, 1560, 1281, 1920, 1280, 1140, 1300, 2060, 2583,
                                     60, 1320, 2280, 1302, 2220, 40, 2905, 2585, 1940, 1160, 1301, 10, 1180,
                                     2403, 2462],                 
            
                    "Label" : ["video games accessories", "books", "stationery", "kitchen and garden", 
                               "interior furniture and bedding", "board games", "interior accessories",
                               "toys for children","goodies", "remote controlled models", "decoration interior",
                               "piscine spa","games and consoles", "early childhood", "magazines", "kids toys",
                               "supplies for domestic animals", "imported video games", "online distribution of video games",
                               "gardening and DIY","Food","playing cards", "accessories children", "adult books",
                               "figurines_wargames", "children books",
                                "games"]
                   }
df_class = pd.DataFrame(data=dict_prdtypecode)
df_class
# Out:
#     prdtypecode                               Label
# 0            50             video games accessories
# 1          2705                               books
# 2          2522                          stationery
# 3          2582                  kitchen and garden
# 4          1560      interior furniture and bedding
# 5          1281                         board games
# 6          1920                interior accessories
# 7          1280                   toys for children
# 8          1140                             goodies
# 9          1300            remote controlled models
# 10         2060                 decoration interior
# 11         2583                         piscine spa
# 12           60                  games and consoles
# 13         1320                     early childhood
# 14         2280                           magazines
# 15         1302                           kids toys
# 16         2220       supplies for domestic animals
# 17           40                imported video games
# 18         2905  online distribution of video games
# 19         2585                   gardening and DIY
# 20         1940                                Food
# 21         1160                       playing cards
# 22         1301                accessories children
# 23           10                         adult books
# 24         1180                  figurines_wargames
# 25         2403                      children books
# 26         2462                               games

# %%
# Crate DF containing prdtypecode , categories and corresponding class used by model
df_class = df_class.sort_values(by = 'prdtypecode', ascending = True)
df_class['target_prdtypecode'] = [i for i in range(27)]
df_class
# Out:
#     prdtypecode                               Label  target_prdtypecode
# 23           10                         adult books                   0
# 17           40                imported video games                   1
# 0            50             video games accessories                   2
# 12           60                  games and consoles                   3
# 8          1140                             goodies                   4
# 21         1160                       playing cards                   5
# 24         1180                  figurines_wargames                   6
# 7          1280                   toys for children                   7
# 5          1281                         board games                   8
# 9          1300            remote controlled models                   9
# 22         1301                accessories children                  10
# 15         1302                           kids toys                  11
# 13         1320                     early childhood                  12
# 4          1560      interior furniture and bedding                  13
# 6          1920                interior accessories                  14
# 20         1940                                Food                  15
# 10         2060                 decoration interior                  16
# 16         2220       supplies for domestic animals                  17
# 14         2280                           magazines                  18
# 25         2403                      children books                  19
# 26         2462                               games                  20
# 2          2522                          stationery                  21
# 3          2582                  kitchen and garden                  22
# 11         2583                         piscine spa                  23
# 19         2585                   gardening and DIY                  24
# 1          2705                               books                  25
# 18         2905  online distribution of video games                  26

# %% [markdown]
# ***Change the 27 product codes to 0 to 26***

# %%
df_train_im.replace({'prdtypecode':{10:0,
                                    40:1,
                                    50:2,
                                    60:3,
                                    1140:4,
                                    1160:5,
                                    1180:6,
                                    1280:7,
                                    1281:8,
                                    1300:9                                    
                                    }}, inplace = True)

df_train_im.replace({'prdtypecode':{1301:10,
                                    1302:11,
                                    1320:12,
                                    1560:13,
                                    1920:14,
                                    1940:15,
                                    2060:16,
                                    2220:17,
                                    2280:18,
                                    2403:19,
                                    2462:20,
                                    2522:21,
                                    2582:22,
                                    2583:23,
                                    2585:24,
                                    2705:25,
                                    2905:26
                                    }}, inplace = True)

# %%
display(df_train_im["prdtypecode"].unique())
# Out:
# array([ 0, 18,  2,  7, 25, 21, 22, 13,  8, 14, 19,  4, 23,  6,  9, 20,  5,
#        16,  1,  3, 12, 11, 17, 26, 24, 15, 10], dtype=int64)

# %% [markdown]
#  ***Convert product code to string type***

# %%
df_train_im["prdtypecode"] = df_train_im["prdtypecode"].astype(str)

# %%
unique, counts = np.unique(df_train_im["prdtypecode"], return_counts=True)
dict(zip(unique, counts))
# Out:
# {'0': 3116,
#  '1': 2508,
#  '10': 807,
#  '11': 2491,
#  '12': 3241,
#  '13': 5073,
#  '14': 4303,
#  '15': 803,
#  '16': 4993,
#  '17': 824,
#  '18': 4760,
#  '19': 4774,
#  '2': 1681,
#  '20': 1421,
#  '21': 4989,
#  '22': 2589,
#  '23': 10209,
#  '24': 2496,
#  '25': 2761,
#  '26': 872,
#  '3': 832,
#  '4': 2671,
#  '5': 3953,
#  '6': 764,
#  '7': 4870,
#  '8': 2070,
#  '9': 5045}

# %% [markdown]
#  ***Split Train Set***

# %%
# Split Train set 
#X_train_im, X_test_im = train_test_split(df_train_im, train_size=0.8, random_state=1234)

# %%
#display(X_train_im.shape)
#display(X_test_im.shape)

# %% [markdown]
# ***Data Generator***

# %%
# %%time
#Générateur de données
img_gen = ImageDataGenerator(rescale = 1/255, 
                             validation_split = 0.2)
# Out:
# Wall time: 0 ns

# %%
img_rows = 224
img_cols = 224
batch_size = 64
epochs = 50

# Directory of images already resized on 256 x 256 
images_dir_train = './data/images/all/image_train_resized/'
#images_dir_train = 'E:/WorkSpace_DataScience_E/Rakuten_Projet_Local/My_WS/data/images/all/image_train_resized/'

# Directory of images org resize 500 x 500
#images_dir_train = './data/images/all/image_train/'
#images_dir_train = 'E:/WorkSpace_DataScience_E/Rakuten_Projet_Local/My_WS/data/images/all/image_train/'

# %%
# %%time

#Itérateur 
train_generator = img_gen.flow_from_dataframe(dataframe = df_train_im,
                                              directory = images_dir_train,
                                              as_ext = True,
                                              x_col = 'imagePath',
                                              y_col = 'prdtypecode',  #target data                                            
                                              class_mode = 'sparse',                                             
                                              target_size = (img_rows , img_cols), # default 256 x 256                                             
                                              batch_size = batch_size,                                             
                                              shuffle = True, # défault
                                              subset = 'training'
                                             )
# Out:
# Found 67933 validated image filenames belonging to 27 classes.
# Wall time: 4.24 s

# %%
# %%time
# validation_split the validation batches ca be retrieved by specifying the subset as validation.
valid_generator = img_gen.flow_from_dataframe(dataframe = df_train_im, 
                                              directory = images_dir_train,
                                              as_ext = True,
                                              x_col = 'imagePath',
                                              y_col = 'prdtypecode',  #target data                                            
                                              class_mode = 'sparse',                                        
                                              target_size = (img_rows , img_cols), # default 256 x 256                                         
                                              batch_size = batch_size, 
                                              shuffle = False,
                                              subset  = 'validation'
                                             )
# Out:
# Found 16983 validated image filenames belonging to 27 classes.
# Wall time: 4.08 s

# %% [markdown]
#  ***MobileNetV2 Implementation***

# %%
# %%time
# Chargement du modèle MobileNetV2
mobileNetV2 = MobileNetV2(weights='imagenet', include_top = False, input_shape=(img_rows,img_rows,3))

# Bloquage du blackbone
for layer in mobileNetV2.layers:
    layer.trainable = False
    
model = Sequential()
model.add(mobileNetV2)
# Ajout des couche de classification
model.add(GlobalAveragePooling2D()) 
model.add(Dense(units = 1024,activation='relu'))

model.add(Dropout(rate = 0.2))
model.add(Dense(units = 512, activation='relu'))

model.add(Dropout(rate = 0.2))
model.add(Dense(units = 27, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1311744
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 27)                13851
# =================================================================
# Total params: 4,108,379
# Trainable params: 1,850,395
# Non-trainable params: 2,257,984
# _________________________________________________________________
# Wall time: 1.36 s

# %% [markdown]
#  ***Compilation***

# %%
# %%time
# Compilation
model.compile(loss='sparse_categorical_crossentropy',  # fonction de perte
              optimizer= Adam(learning_rate= 1e-5) ,   #default lr = 0.001 # algorithme de descente de gradient
              metrics=['accuracy'])                    # métrique d'évaluation
# Out:
# Wall time: 198 ms

# %% [markdown]
# ***Callbacks***

# %%
# %%time
path = './saves/MobileNetV2/Iteration_4_3/'
file_name = 'checkpoint_MobileNetV2_21122021_50Epochs.h5'

#Sauvegarder les meilleurs poids du modèle au cours de l'entraînement :
checkpoint = ModelCheckpoint(filepath = path + file_name , 
                             monitor ='val_accuracy',
                             verbose = 1,
                             save_best_only = True, # (pour que le meilleur modèle ne soit pas écrasé)
                             save_weights_only = False,
                             mode ='max', #(permet de préciser si la métrique doit croître ou décroitre : ici on choisit 'min'
                                           #car la métrique est une perte à minimiser)
                             save_freq='epoch')
#Arrêter l'entraînement si le modèle n'évolue plus (très pratique pour ne pas gérer le
#nombre d'epoch) :
early = EarlyStopping(monitor='val_loss',
                      min_delta = 0,
                      patience = 10, #(nombre d'epochs à attendre avant d'arrêter l'entraînement
                      restore_best_weights = True,
                      verbose = 1,
                      mode = 'min')

#Réduire automatiquement le learning rate :
lr_plateau = ReduceLROnPlateau(monitor = 'val_loss',
                               patience = 10,
                               verbose = 1,
                                mode='min'
                               )
# Out:
# Wall time: 0 ns

# %% [markdown]
#  ***Fit - train_generator***

# %%
step_size_Train = train_generator.n//train_generator.batch_size
step_size_Valid = valid_generator.n//valid_generator.batch_size
print('step_size_Train : ' , step_size_Train)
print('step_size_Valid  : ' , step_size_Valid)
# Out:
# step_size_Train :  1061
# step_size_Valid  :  265

# %%
# %%time
# Fit Train generator
history = model.fit(train_generator,                    
                    epochs = epochs,                   
                    steps_per_epoch = step_size_Train, 
                    validation_data = valid_generator,
                    validation_steps = step_size_Valid,
                    callbacks=[checkpoint, early, lr_plateau]
                    
                    )
# Out:
# Epoch 1/50
# 1061/1061 [==============================] - 91s 85ms/step - loss: 2.0250 - accuracy: 0.4178 - val_loss: 1.8313 - val_accuracy: 0.4700
#
# Epoch 00001: val_accuracy improved from 0.42647 to 0.47005, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 2/50
# 1061/1061 [==============================] - 91s 86ms/step - loss: 1.8758 - accuracy: 0.4538 - val_loss: 1.7407 - val_accuracy: 0.4936
#
# Epoch 00002: val_accuracy improved from 0.47005 to 0.49357, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 3/50
# 1061/1061 [==============================] - 97s 91ms/step - loss: 1.7910 - accuracy: 0.4762 - val_loss: 1.6854 - val_accuracy: 0.5081
#
# Epoch 00003: val_accuracy improved from 0.49357 to 0.50808, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 4/50
# 1061/1061 [==============================] - 98s 92ms/step - loss: 1.7282 - accuracy: 0.4906 - val_loss: 1.6446 - val_accuracy: 0.5213
#
# Epoch 00004: val_accuracy improved from 0.50808 to 0.52129, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 5/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.6814 - accuracy: 0.5030 - val_loss: 1.6166 - val_accuracy: 0.5261
#
# Epoch 00005: val_accuracy improved from 0.52129 to 0.52606, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 6/50
# 1061/1061 [==============================] - 91s 85ms/step - loss: 1.6411 - accuracy: 0.5131 - val_loss: 1.5886 - val_accuracy: 0.5331
#
# Epoch 00006: val_accuracy improved from 0.52606 to 0.53308, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 7/50
# 1061/1061 [==============================] - 91s 85ms/step - loss: 1.6089 - accuracy: 0.5232 - val_loss: 1.5681 - val_accuracy: 0.5395
#
# Epoch 00007: val_accuracy improved from 0.53308 to 0.53950, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 8/50
# 1061/1061 [==============================] - 91s 86ms/step - loss: 1.5793 - accuracy: 0.5331 - val_loss: 1.5489 - val_accuracy: 0.5445
#
# Epoch 00008: val_accuracy improved from 0.53950 to 0.54452, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 9/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.5497 - accuracy: 0.5386 - val_loss: 1.5338 - val_accuracy: 0.5483
#
# Epoch 00009: val_accuracy improved from 0.54452 to 0.54829, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 10/50
# 1061/1061 [==============================] - 91s 86ms/step - loss: 1.5230 - accuracy: 0.5464 - val_loss: 1.5188 - val_accuracy: 0.5517
#
# Epoch 00010: val_accuracy improved from 0.54829 to 0.55171, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 11/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.5003 - accuracy: 0.5551 - val_loss: 1.5069 - val_accuracy: 0.5553
#
# Epoch 00011: val_accuracy improved from 0.55171 to 0.55531, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 12/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.4782 - accuracy: 0.5594 - val_loss: 1.4949 - val_accuracy: 0.5578
#
# Epoch 00012: val_accuracy improved from 0.55531 to 0.55784, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 13/50
# 1061/1061 [==============================] - 92s 87ms/step - loss: 1.4617 - accuracy: 0.5651 - val_loss: 1.4834 - val_accuracy: 0.5607
#
# Epoch 00013: val_accuracy improved from 0.55784 to 0.56067, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 14/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.4381 - accuracy: 0.5706 - val_loss: 1.4725 - val_accuracy: 0.5634
#
# Epoch 00014: val_accuracy improved from 0.56067 to 0.56338, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 15/50
# 1061/1061 [==============================] - 94s 88ms/step - loss: 1.4208 - accuracy: 0.5760 - val_loss: 1.4637 - val_accuracy: 0.5682
#
# Epoch 00015: val_accuracy improved from 0.56338 to 0.56822, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 16/50
# 1061/1061 [==============================] - 99s 93ms/step - loss: 1.4044 - accuracy: 0.5774 - val_loss: 1.4555 - val_accuracy: 0.5695
#
# Epoch 00016: val_accuracy improved from 0.56822 to 0.56946, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 17/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.3881 - accuracy: 0.5841 - val_loss: 1.4469 - val_accuracy: 0.5690
#
# Epoch 00017: val_accuracy did not improve from 0.56946
# Epoch 18/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.3690 - accuracy: 0.5903 - val_loss: 1.4408 - val_accuracy: 0.5717
#
# Epoch 00018: val_accuracy improved from 0.56946 to 0.57170, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 19/50
# 1061/1061 [==============================] - 89s 84ms/step - loss: 1.3521 - accuracy: 0.5947 - val_loss: 1.4326 - val_accuracy: 0.5748
#
# Epoch 00019: val_accuracy improved from 0.57170 to 0.57476, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 20/50
# 1061/1061 [==============================] - 90s 85ms/step - loss: 1.3408 - accuracy: 0.5990 - val_loss: 1.4267 - val_accuracy: 0.5757
#
# Epoch 00020: val_accuracy improved from 0.57476 to 0.57571, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 21/50
# 1061/1061 [==============================] - 91s 86ms/step - loss: 1.3252 - accuracy: 0.6014 - val_loss: 1.4207 - val_accuracy: 0.5777
#
# Epoch 00021: val_accuracy improved from 0.57571 to 0.57771, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 22/50
# 1061/1061 [==============================] - 94s 88ms/step - loss: 1.3093 - accuracy: 0.6057 - val_loss: 1.4148 - val_accuracy: 0.5785
#
# Epoch 00022: val_accuracy improved from 0.57771 to 0.57848, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 23/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.2957 - accuracy: 0.6082 - val_loss: 1.4090 - val_accuracy: 0.5795
#
# Epoch 00023: val_accuracy improved from 0.57848 to 0.57948, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 24/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.2806 - accuracy: 0.6125 - val_loss: 1.4042 - val_accuracy: 0.5829
#
# Epoch 00024: val_accuracy improved from 0.57948 to 0.58290, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 25/50
# 1061/1061 [==============================] - 92s 87ms/step - loss: 1.2701 - accuracy: 0.6183 - val_loss: 1.3987 - val_accuracy: 0.5839
#
# Epoch 00025: val_accuracy improved from 0.58290 to 0.58390, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 26/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.2557 - accuracy: 0.6217 - val_loss: 1.3931 - val_accuracy: 0.5858
#
# Epoch 00026: val_accuracy improved from 0.58390 to 0.58579, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 27/50
# 1061/1061 [==============================] - 92s 86ms/step - loss: 1.2418 - accuracy: 0.6253 - val_loss: 1.3897 - val_accuracy: 0.5859
#
# Epoch 00027: val_accuracy improved from 0.58579 to 0.58591, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 28/50
# 1061/1061 [==============================] - 92s 87ms/step - loss: 1.2323 - accuracy: 0.6252 - val_loss: 1.3879 - val_accuracy: 0.5876
# Epoch 00028: val_accuracy improved from 0.58591 to 0.58756, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 29/50
# 1061/1061 [==============================] - 92s 87ms/step - loss: 1.2185 - accuracy: 0.6324 - val_loss: 1.3827 - val_accuracy: 0.5891
#
# Epoch 00029: val_accuracy improved from 0.58756 to 0.58909, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 30/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.2065 - accuracy: 0.6363 - val_loss: 1.3776 - val_accuracy: 0.5907
#
# Epoch 00030: val_accuracy improved from 0.58909 to 0.59074, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 31/50
# 1061/1061 [==============================] - 92s 86ms/step - loss: 1.1906 - accuracy: 0.6389 - val_loss: 1.3750 - val_accuracy: 0.5914
#
# Epoch 00031: val_accuracy improved from 0.59074 to 0.59139, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 32/50
# 1061/1061 [==============================] - 94s 89ms/step - loss: 1.1824 - accuracy: 0.6429 - val_loss: 1.3734 - val_accuracy: 0.5927
#
# Epoch 00032: val_accuracy improved from 0.59139 to 0.59269, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 33/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.1711 - accuracy: 0.6464 - val_loss: 1.3689 - val_accuracy: 0.5940
#
# Epoch 00033: val_accuracy improved from 0.59269 to 0.59399, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 34/50
# 1061/1061 [==============================] - 92s 86ms/step - loss: 1.1606 - accuracy: 0.6490 - val_loss: 1.3648 - val_accuracy: 0.5961
#
# Epoch 00034: val_accuracy improved from 0.59399 to 0.59611, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 35/50
# 1061/1061 [==============================] - 92s 87ms/step - loss: 1.1458 - accuracy: 0.6510 - val_loss: 1.3635 - val_accuracy: 0.5965
#
# Epoch 00035: val_accuracy improved from 0.59611 to 0.59652, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 36/50
# 1061/1061 [==============================] - 92s 87ms/step - loss: 1.1385 - accuracy: 0.6552 - val_loss: 1.3612 - val_accuracy: 0.5965
#
# Epoch 00036: val_accuracy did not improve from 0.59652
# Epoch 37/50
# 1061/1061 [==============================] - 91s 86ms/step - loss: 1.1266 - accuracy: 0.6584 - val_loss: 1.3571 - val_accuracy: 0.5977
#
# Epoch 00037: val_accuracy improved from 0.59652 to 0.59770, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 38/50
# 1061/1061 [==============================] - 91s 86ms/step - loss: 1.1170 - accuracy: 0.6607 - val_loss: 1.3557 - val_accuracy: 0.5977
#
# Epoch 00038: val_accuracy did not improve from 0.59770
# Epoch 39/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.1057 - accuracy: 0.6637 - val_loss: 1.3530 - val_accuracy: 0.5987
#
# Epoch 00039: val_accuracy improved from 0.59770 to 0.59870, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 40/50
# 1061/1061 [==============================] - 92s 86ms/step - loss: 1.0938 - accuracy: 0.6669 - val_loss: 1.3514 - val_accuracy: 0.6026
#
# Epoch 00040: val_accuracy improved from 0.59870 to 0.60259, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 41/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.0845 - accuracy: 0.6698 - val_loss: 1.3490 - val_accuracy: 0.6005
#
# Epoch 00041: val_accuracy did not improve from 0.60259
# Epoch 42/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.0735 - accuracy: 0.6742 - val_loss: 1.3487 - val_accuracy: 0.6006
#
# Epoch 00042: val_accuracy did not improve from 0.60259
# Epoch 43/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.0651 - accuracy: 0.6759 - val_loss: 1.3451 - val_accuracy: 0.6021
#
# Epoch 00043: val_accuracy did not improve from 0.60259
# Epoch 44/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.0536 - accuracy: 0.6786 - val_loss: 1.3431 - val_accuracy: 0.6021
#
# Epoch 00044: val_accuracy did not improve from 0.60259
# Epoch 45/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.0415 - accuracy: 0.6832 - val_loss: 1.3443 - val_accuracy: 0.6009
#
# Epoch 00045: val_accuracy did not improve from 0.60259
# Epoch 46/50
# 1061/1061 [==============================] - 93s 87ms/step - loss: 1.0317 - accuracy: 0.6870 - val_loss: 1.3414 - val_accuracy: 0.6039
#
# Epoch 00046: val_accuracy improved from 0.60259 to 0.60389, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 47/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 1.0220 - accuracy: 0.6878 - val_loss: 1.3390 - val_accuracy: 0.6047
#
# Epoch 00047: val_accuracy improved from 0.60389 to 0.60466, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 48/50
# 1061/1061 [==============================] - 94s 89ms/step - loss: 1.0108 - accuracy: 0.6903 - val_loss: 1.3378 - val_accuracy: 0.6054
#
# Epoch 00048: val_accuracy improved from 0.60466 to 0.60537, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 49/50
# 1061/1061 [==============================] - 92s 87ms/step - loss: 1.0018 - accuracy: 0.6938 - val_loss: 1.3370 - val_accuracy: 0.6060
#
# Epoch 00049: val_accuracy improved from 0.60537 to 0.60601, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Epoch 50/50
# 1061/1061 [==============================] - 93s 88ms/step - loss: 0.9935 - accuracy: 0.6965 - val_loss: 1.3381 - val_accuracy: 0.6062
#
# Epoch 00050: val_accuracy improved from 0.60601 to 0.60619, saving model to ./saves/MobileNetV2/Iteration_4_3\checkpoint_MobileNetV2_21122021_50Epochs.h5
# Wall time: 1h 17min 22s

# %% [markdown]
# ***Save History results***

# %%
# Save History results
path = './saves/MobileNetV2/Iteration_4_3/'
filename = 'history_MobileNetV2_all_train_21122021_50Epochs'

# %%
#convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# history to json:  
hist_json_file = path + filename + '.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# history to csv: 
hist_csv_file = path + filename +'.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# history to pickle file
hist_df.to_pickle(path + filename +'.pkl')

# %% [markdown]
# ***Display Model loss , accuracy per epoch***

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model acc by epoch')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='right')
plt.show()

# %% [markdown]
#  ***Prediction - test_generator***

# %%
# %%time
#Prediction - Valid set
y_pred_proba = model.predict(valid_generator)

# l'argmax pour obtenir les classes prédites
y_pred_class = np.argmax(y_pred_proba,axis = 1).astype(int)

# To get classes from test generator
y_true = valid_generator.classes
# Out:
# Wall time: 18.9 s

# %% [markdown]
#  ***Evaluation - test_generator***

# %%
# %%time
#Get the accuracy score
valid_score = model.evaluate(valid_generator)
print("[INFO] Model metrics names:", model.metrics_names)
print("[INFO] Accuracy: {:.2f}%".format(valid_score[1] * 100)) 
print("[INFO] Loss: ",valid_score[0])
# Out:
# 266/266 [==============================] - 19s 69ms/step - loss: 1.3377 - accuracy: 0.6063
# [INFO] Model metrics names: ['loss', 'accuracy']
# [INFO] Accuracy: 60.63%
# [INFO] Loss:  1.3377368450164795
# Wall time: 18.7 s

# %%
f1_macro = f1_score(y_true, y_pred_class, average='macro')
print("[INFO] f1 score macro average: ",f1_macro)

f1_micro = f1_score(y_true, y_pred_class, average='micro')
print("[INFO] f1 score micro average: ",f1_micro)

f1_weighted = f1_score(y_true, y_pred_class, average='weighted')
print("[INFO] f1 score weighted average: ",f1_weighted)
# Out:
# [INFO] f1 score macro average:  0.5484094485274825
# [INFO] f1 score micro average:  0.6063121945474886
# [INFO] f1 score weighted average:  0.5959134865266176

# %%
#Confusion matrix
matrix = confusion_matrix(y_true, y_pred_class)
fig , ax = plt.subplots(figsize = (24,20))
ax.matshow(matrix, cmap = plt.cm.Oranges , alpha = 0.3)
for i in range(matrix.shape[0]):
    for j in range (matrix.shape[1]):
        ax.text (x = j , y= i, s= matrix[i,j], va = 'center', ha = 'center', size = 'xx-large')
        
plt.xlabel('predicted', fontsize = 18)
plt.ylabel('Acutals', fontsize = 18)
plt.title('Confusion Matrix', fontsize = 18)
plt.show()
#print(matrix)

# %%
print(metrics.classification_report(y_true, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.55      0.54       621
#            1       0.47      0.48      0.48       483
#            2       0.61      0.55      0.58       154
#            3       0.45      0.30      0.36       508
#            4       0.54      0.39      0.45       656
#            5       0.57      0.59      0.58      1038
#            6       0.76      0.80      0.78       848
#            7       0.62      0.58      0.60       152
#            8       0.45      0.55      0.50      1021
#            9       0.54      0.30      0.39       168
#           10       0.67      0.71      0.69       956
#           11       0.61      0.63      0.62       939
#           12       0.52      0.29      0.37       375
#           13       0.57      0.43      0.49       290
#           14       0.66      0.70      0.68       949
#           15       0.52      0.35      0.41       508
#           16       0.74      0.87      0.80      2061
#           17       0.41      0.37      0.39       493
#           18       0.67      0.74      0.70       548
#           19       0.57      0.60      0.58       173
#           20       0.66      0.75      0.70       163
#           21       0.62      0.58      0.60       546
#           22       0.88      0.88      0.88       791
#           23       0.55      0.25      0.34       154
#           24       0.42      0.43      0.43       963
#           25       0.33      0.17      0.22       405
#           26       0.59      0.75      0.66      1020
#
#     accuracy                           0.61     16983
#    macro avg       0.57      0.54      0.55     16983
# weighted avg       0.60      0.61      0.60     16983

# %% [markdown]
#  ***Predict input image using trained model***

# %%
# Predict With Pre Trained

# Load an image
im_id = 101
img_path ='./data/images/all/image_train_resized/'+ df_train_im['imagePath'][im_id]

img = image.load_img(img_path,target_size=(224, 224))
plt.figure(figsize=(6,4))
plt.imshow(img)
plt.title("class: " + str(df_train_im['prdtypecode'][im_id]))
plt.xticks([])
plt.yticks([])
#plt.axis('off')
plt.show();

# %%
im = cv2.resize(cv2.imread(img_path), (224, 224))
im = np.expand_dims(im, axis=0)

# %%
out = model.predict(im)
print("------------------Predicted Class and Label ------------------------------")
print("target class(used by model) :", np.argmax(out))
print("\n"  ,df_class[df_class['target_prdtypecode'] == np.argmax(out)][['prdtypecode', 'Label']].to_string(index=False)) 

prd_code = df_train_im['prdtypecode'][im_id]

print("\n\n------------------Real Class and Label ------------------------------")
print("target class(used by model): " ,  df_class[df_class['target_prdtypecode'] == int(prd_code)]['target_prdtypecode'].to_string(index=False))
print("\n"  ,df_class[df_class['target_prdtypecode'] == int(prd_code)][['prdtypecode', 'Label']].to_string(index=False))
# Out:
# ------------------Predicted Class and Label ------------------------------
# target class(used by model) : 8
#
#   prdtypecode       Label
#         1281 board games
#
#
# ------------------Real Class and Label ------------------------------
# target class(used by model):  1
#
#   prdtypecode                Label
#           40 imported video games

# %% [markdown]
#  ***Save MobileNetV2 Model***

# %%
#Enregistrement du modèle
model.save("./saves/MobileNetV2/Iteration_4_3/Model_MobileNetV2_All_train_data_21122021_5Epochs.hdf5")
#The SavedModel and HDF5 file contains:
#the model's configuration (topology)
#the model's weights
#the model's optimizer's state (if any)

# %% [markdown]
#  ***Load MobileNetV2 Model***

# %%
#Rechargement du modèle :
model = load_model('./saves/MobileNetV2/Iteration_4_3/Model_MobileNetV2_All_train_data_21122021_5Epochs.hdf5')
