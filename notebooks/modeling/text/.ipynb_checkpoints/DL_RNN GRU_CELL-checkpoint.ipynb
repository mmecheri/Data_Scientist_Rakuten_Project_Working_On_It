# %%
import pandas as pd
import numpy as np

# %%
y = pd.read_pickle('ytrain.pkl')

# %%
X = pd.read_pickle('x_train_new.pkl')

# %%
X.head()
# Out:
#                                          designation  \
# 0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                               <NA>  3804725264  1263597046
# 1                                               <NA>   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                               <NA>    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#                                                 text
# 0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3  Peluche Donald - Europe Disneyland 2000 (Mario...
# 4  La Guerre Des TuquesLuc a des id&eacute;es de ...

# %%
#!pip install swifter

# %%
import re
import unicodedata
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import swifter

stop_words = stopwords.words('french') + stopwords.words('english') + stopwords.words('german') +['plus', 'peut', 'tout', 'etre', 'sans', 'dont', 'aussi', 'comme', 'meme', 'bien','leurs', 'elles', 'cette','celui', 'ainsi', 'encore', 'alors', 'toujours', 'toute','deux', 'nouveau', 'peu', 'car', 'autre', 'jusqu', 'quand', 'ici', 'ceux', 'enfin', 'jamais', 'autant', 'tant', 'avoir', 'moin', 'celle', 'tous', 'contre', 'pourtant', 'quelque', 'toutes', 'surtout', 'cet', 'comment', 'rien', 'avant', 'doit', 'autre', 'depuis', 'moins', 'tre', 'souvent', 'etait', 'pouvoir', 'apre', 'non', 'ver', 'quel', 'pourquoi', 'certain', 'fait', 'faire', 'sou', 'donc', 'trop', 'quelques', 'parfois', 'tres', 'donc', 'dire', 'eacute', 'egrave', 'rsquo', 'agrave', 'ecirc', 'nbsp', 'acirc', 'apres', 'autres', 'ocirc', 'entre', 'sous', 'quelle']

# Converts the unicode file to ascii
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

def preprocess_sentence(w):
    w = unicode_to_ascii(w.lower().strip())
    # creating a space between a word and the punctuation following it
    # eg: "he is a boy." => "he is a boy ."
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
    w = re.sub(r"[^a-zA-Z?.!]+", " ", w)
    w = re.sub(r'\b\w{0,2}\b', '', w)

    # remove stopword
    mots = word_tokenize(w.strip())
    mots = [mot for mot in mots if mot not in stop_words]
    return ' '.join(mots).strip()

X.text = X.text.swifter.apply(lambda x :preprocess_sentence(x))
X.head()
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]
#                                          designation  \
# 0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                               <NA>  3804725264  1263597046
# 1                                               <NA>   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                               <NA>    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
#
#                                                 text
# 0  olivia personalisiertes notizbuch seiten punkt...
# 1  journal arts art marche salon art asiatique pa...
# 2  grand stylet ergonomique bleu gamepad nintendo...
# 3  peluche donald europe disneyland marionnette d...
# 4  guerre tuquesluc grandeur . veut organiser jeu...

# %%
from sklearn.model_selection import train_test_split
X_text_train, X_text_test, y_train, y_test = train_test_split(X.text, y, test_size=0.2, random_state=1234)

# %%
import tensorflow as tf
# Définition du tokenizer
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=10000)
# Mettre à jour le dictionnaire du tokenizer
tokenizer.fit_on_texts(X_text_train)

# %%
# Définition des dictionnaires
word2idx = tokenizer.word_index
idx2word = tokenizer.index_word
vocab_size = tokenizer.num_words

# %%
X_train = tokenizer.texts_to_sequences(X_text_train)

# %%
X_test = tokenizer.texts_to_sequences(X_text_test)

# %%
#Transfomer la liste de sequence X_train en tableau numpy à l'aide de la fonction pad_sequences
maxlen = 500
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, maxlen=maxlen, padding='post')

# %%
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, maxlen=maxlen, padding='post')

# %% [markdown]
# # Modèle : RNN GRUCELL

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, RNN, GRUCell, Dropout
embedding_dim = 200

model = Sequential()
model.add(Embedding(10000, embedding_dim))
model.add(RNN(GRUCell(128), return_sequences=True))
model.add(Dropout(0.3))
model.add(GlobalAveragePooling1D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(27, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 200)         2000000
#
#  rnn (RNN)                   (None, None, 128)         126720
#
#  dropout (Dropout)           (None, None, 128)         0
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 256)               33024
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 27)                6939
#
# =================================================================
# Total params: 2,166,683
# Trainable params: 2,166,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


history = model.fit(X_train, y_train.values,
    batch_size = 64,
    epochs=10,
    validation_data = [X_test, y_test.values])
# Out:
# Epoch 1/10
# 1062/1062 [==============================] - 716s 673ms/step - loss: 1.8252 - accuracy: 0.4459 - val_loss: 1.0365 - val_accuracy: 0.6933
# Epoch 2/10
# 1062/1062 [==============================] - 917s 863ms/step - loss: 0.8574 - accuracy: 0.7448 - val_loss: 0.8269 - val_accuracy: 0.7515
# Epoch 3/10
# 1062/1062 [==============================] - 973s 916ms/step - loss: 0.6405 - accuracy: 0.8073 - val_loss: 0.7800 - val_accuracy: 0.7695
# Epoch 4/10
# 1062/1062 [==============================] - 987s 930ms/step - loss: 0.5184 - accuracy: 0.8416 - val_loss: 0.8093 - val_accuracy: 0.7714
# Epoch 5/10
# 1062/1062 [==============================] - 985s 928ms/step - loss: 0.4349 - accuracy: 0.8661 - val_loss: 0.8647 - val_accuracy: 0.7738
# Epoch 6/10
# 1062/1062 [==============================] - 949s 894ms/step - loss: 0.3658 - accuracy: 0.8859 - val_loss: 0.9343 - val_accuracy: 0.7699
# Epoch 7/10
# 1062/1062 [==============================] - 955s 899ms/step - loss: 0.3167 - accuracy: 0.9005 - val_loss: 1.0025 - val_accuracy: 0.7660
# Epoch 8/10
# 1062/1062 [==============================] - 949s 894ms/step - loss: 0.2768 - accuracy: 0.9116 - val_loss: 1.0622 - val_accuracy: 0.7711
# Epoch 9/10
# 1062/1062 [==============================] - 962s 906ms/step - loss: 0.2427 - accuracy: 0.9223 - val_loss: 1.1536 - val_accuracy: 0.7708
# Epoch 10/10
# 1062/1062 [==============================] - 956s 900ms/step - loss: 0.2149 - accuracy: 0.9292 - val_loss: 1.2399 - val_accuracy: 0.7712

# %%
model.evaluate(X_test, y_test.values, batch_size=128)
# Out:
# 133/133 [==============================] - 51s 383ms/step - loss: 1.2399 - accuracy: 0.7712
# [1.2398518323898315, 0.7711964249610901]

# %%
y_pred = model.predict(X_test)
#Appliquer la méthode argmax du tableau y_pred pour obtenir les classes les plus probable

y_pred_class = y_pred.argmax(axis = 1)
#y_test_class = y_test.argmax(axis = 1)

# %%
from sklearn import metrics

import matplotlib.pyplot as plt
# %matplotlib inline
import itertools

def conf_mat(y_test,y_pred):

    cnf_matrix = metrics.confusion_matrix(y_test, y_pred)

    classes = range(0,27)

    plt.figure(figsize=(20,20))
    plt.imshow(cnf_matrix, interpolation='nearest',cmap='Blues')
    plt.title("Matrice de confusion")
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
        plt.text(j, i, cnf_matrix[i, j],
              horizontalalignment = "center",
              color = "white" if cnf_matrix[i, j] > ( cnf_matrix.max() / 2) else "black")

    plt.ylabel('Vrais labels')
    plt.xlabel('Labels prédits')
    plt.show()

# %%
conf_mat(y_test,y_pred_class)

# %%
cnf_matrix = metrics.confusion_matrix(y_test,y_pred_class)
for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
      if(cnf_matrix[i,j] >20 and i!=j):
          print("the classe {0} is often taken as the classe {1} , no of errors = {2}".format(i,j,cnf_matrix[i,j]))
# Out:
# the classe 0 is often taken as the classe 1 , no of errors = 102
# the classe 0 is often taken as the classe 4 , no of errors = 66
# the classe 0 is often taken as the classe 10 , no of errors = 85
# the classe 1 is often taken as the classe 0 , no of errors = 87
# the classe 1 is often taken as the classe 4 , no of errors = 40
# the classe 1 is often taken as the classe 10 , no of errors = 77
# the classe 3 is often taken as the classe 8 , no of errors = 52
# the classe 3 is often taken as the classe 11 , no of errors = 56
# the classe 3 is often taken as the classe 14 , no of errors = 91
# the classe 3 is often taken as the classe 20 , no of errors = 28
# the classe 4 is often taken as the classe 0 , no of errors = 66
# the classe 4 is often taken as the classe 1 , no of errors = 59
# the classe 4 is often taken as the classe 10 , no of errors = 39
# the classe 6 is often taken as the classe 7 , no of errors = 49
# the classe 6 is often taken as the classe 24 , no of errors = 32
# the classe 7 is often taken as the classe 6 , no of errors = 28
# the classe 7 is often taken as the classe 9 , no of errors = 29
# the classe 7 is often taken as the classe 17 , no of errors = 45
# the classe 7 is often taken as the classe 20 , no of errors = 25
# the classe 7 is often taken as the classe 24 , no of errors = 24
# the classe 8 is often taken as the classe 3 , no of errors = 84
# the classe 9 is often taken as the classe 17 , no of errors = 23
# the classe 10 is often taken as the classe 0 , no of errors = 72
# the classe 10 is often taken as the classe 1 , no of errors = 106
# the classe 10 is often taken as the classe 4 , no of errors = 27
# the classe 11 is often taken as the classe 3 , no of errors = 32
# the classe 14 is often taken as the classe 3 , no of errors = 65
# the classe 15 is often taken as the classe 18 , no of errors = 27
# the classe 16 is often taken as the classe 0 , no of errors = 73
# the classe 17 is often taken as the classe 6 , no of errors = 22
# the classe 17 is often taken as the classe 7 , no of errors = 50
# the classe 17 is often taken as the classe 9 , no of errors = 37
# the classe 18 is often taken as the classe 0 , no of errors = 53
# the classe 20 is often taken as the classe 3 , no of errors = 26
# the classe 20 is often taken as the classe 17 , no of errors = 27
# the classe 21 is often taken as the classe 3 , no of errors = 25
